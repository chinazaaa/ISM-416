# %%
## Scrape any two articles of choice, summarize them and perform NLP taskson the summaries

# %% [markdown]
# #### Chinaza Obiekwe. 17100310846

# %%
import requests
from bs4 import BeautifulSoup
import gensim
import docx
import spacy
import pandas as pd
nlp = spacy.load('en_core_web_sm')

# %%
url = 'https://www.bbc.com/news/world-africa-56993215'
print("Your url is :", url)
page = requests.get(url).text
print(page)
soup = BeautifulSoup(page)
print(soup)
header = soup.find('h1').get_text()
header2 = 'Summary'
date = soup.find('time', attrs = {'data-testid': 'timestamp'}).text
p_tags = soup.findAll('p')
#strip removes space
text = [tags.get_text().strip() for tags in p_tags]
print(text)
#remove everything thats not new line
sentence_list = [ sentence for sentence in text if not '\n' in sentence]
sentence_list = [ sentence for sentence in sentence_list if '.' in sentence]
article = ''.join(sentence_list)
from gensim.summarization import summarize
summary = summarize(article, ratio = 0.15)
doc = docx.Document()
doc.add_heading(header)
doc.add_picture('picture.png')
doc.add_paragraph(date)
doc.add_paragraph(article)
doc.add_heading(header2)
doc.add_paragraph(summary)
doc.save('documentAssignment.doc')
# Out:
# Your url is : https://www.bbc.com/news/world-africa-56993215
# <!DOCTYPE html><html lang="en-GB" class="no-js"><head><meta charSet="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1" /><title data-rh="true">South Africa&#x27;s Zulu royals: Whoâs who in the fight for the throne - BBC News</title><meta data-rh="true" name="description" content="The monarchy is plunged into controversy following the death of the king and the regent."/><meta data-rh="true" name="theme-color" content="#FFFFFF"/><meta data-rh="true" property="article:author" content="https://www.facebook.com/bbcnews"/><meta data-rh="true" property="fb:admins" content="100004154058350"/><meta data-rh="true" property="fb:app_id" content="1609039196070050"/><meta data-rh="true" property="fb:pages" content="1143803202301544,317278538359186,1392506827668140,742734325867560,185246968166196,156060587793370,137920769558355,193435954068976,21263239760,156400551056385,929399697073756,154344434967,228735667216,80758950658,260212261199,294662213128,1086451581439054,283348121682053,295830058648,239931389545417,304314573046,310719525611571,647687225371774,1159932557403143,286567251709437,1731770190373618,125309456546,163571453661989,285361880228,512423982152360,238003846549831,176663550714,260967092113,118450564909230,100978706649892,15286229625,122103087870579,120655094632228,102814153147070,124715648647,153132638110668,150467675018739"/><meta data-rh="true" property="og:description" content="The monarchy is plunged into controversy following the death of the king and the regent."/><meta data-rh="true" property="og:image" content="https://ichef.bbci.co.uk/news/1024/branded_news/10EEE/production/_118385396_zulu3.jpg"/><meta data-rh="true" property="og:image:alt" content="Zulu Warriors at the funeral service of King Goodwill Zwelithini KaBhekuzulu on March 18, 2021 in Nongoma, South Africa."/><meta data-rh="true" property="og:locale" content="en_GB"/><meta data-rh="true" property="og:site_name" content="BBC News"/><meta data-rh="true" property="og:title" content="South Africa&#x27;s Zulu royals: Whoâs who in the fight for the throne"/><meta data-rh="true" property="og:type" content="article"/><meta data-rh="true" property="og:url" content="https://www.bbc.com/news/world-africa-56993215"/><meta data-rh="true" property="article:section" content="Africa"/><meta data-rh="true" name="twitter:card" content="summary_large_image"/><meta data-rh="true" name="twitter:creator" content="@BBCWorld"/><meta data-rh="true" name="twitter:description" content="The monarchy is plunged into controversy following the death of the king and the regent."/><meta data-rh="true" name="twitter:domain" content="www.bbc.com"/><meta data-rh="true" name="twitter:image:src" content="https://ichef.bbci.co.uk/news/1024/branded_news/10EEE/production/_118385396_zulu3.jpg"/><meta data-rh="true" name="twitter:image:alt" content="Zulu Warriors at the funeral service of King Goodwill Zwelithini KaBhekuzulu on March 18, 2021 in Nongoma, South Africa."/><meta data-rh="true" name="twitter:site" content="@BBCWorld"/><meta data-rh="true" name="twitter:title" content="South Africa&#x27;s Zulu royals: Whoâs who in the fight for the throne"/><meta data-rh="true" type="metaTags" name="application-name" content="BBC News"/><meta data-rh="true" type="metaTags" name="mobile-web-app-capable" content="yes"/><meta data-rh="true" type="metaTags" name="msapplication-TileImage" content="BBC News"/><meta data-rh="true" type="metaTags" name="msapplication-TileColor" content="#bb1919"/><meta data-rh="true" type="metaTags" name="cleartype" http-equiv="cleartype" content="on"/><link data-rh="true" rel="canonical" href="https://www.bbc.com/news/world-africa-56993215"/><link data-rh="true" rel="amphtml" href="https://www.bbc.com/news/world-africa-56993215.amp"/><link data-rh="true" rel="alternate" hrefLang="en-gb" href="https://www.bbc.co.uk/news/world-africa-56993215"/><link data-rh="true" rel="alternate" hrefLang="en" href="https://www.bbc.com/news/world-africa-56993215"/>< ...
# /**
# * https://gist.github.com/samthor/64b114e4a4f539915a95b91ffd340acc
# */
# (function() {
#   var check = document.createElement('script');
#   if (!('noModule' in check) && 'onbeforeload' in check) {
#     var support = false;
#     document.addEventListener('beforeload', function(e) {
#       if (e.target === check) {
#         support = true;
#       } else if (!e.target.hasAttribute('nomodule') || !support) {
#         return;
#       }
#       e.preventDefault();
#     }, true);
#
#     check.type = 'module';
#     check.src = '.';
#     document.head.appendChild(check);
#     check.remove();
#   }
# }());
# </script><script nonce="CIzzZ6hTcyKSHesXXX1G0KjFMTvlqTZVt466dg2WcG1cXPYBMW">document.querySelector("html").classList.remove("no-js")</script><style data-emotion-css="10943lf 181c4hk-SectionWrapper 1c70a0k-HeaderSection 1wqums9-GlobalNavigation 1ocoo3l-Wrap 1va5u92-GlobalNavigationContent zfamng-GlobalNavigationSide 1m0vj5n-GlobalNavigationItem sz8ckn-NavigationLink-LogoLink 1pfj44u-LogoIconWrapper xi5oyi-StyledIcon 1f39n02-VisuallyHidden y0ubc0-AccessibilityLink vp47zn-GlobalNavigationLinkList-En d5c0hm-GlobalNavigationProduct-GlobalNavigationNonProductItem-GlobalNavigationAccount br3q78-NavigationLink-AccountLink q3rgld-AccountIconWrapper qgttmg-AccountText so3uhw-GlobalNavigationProduct 4aca3d-NavigationLink 13icshe-NavigationLink 1j1nxpl-NavigationLink 1doc5cp-NavigationLink 1g0nxtm-NavigationLink 13rbivf-NavigationLink f5m96n-NavigationLink jyg7lk-NavigationLink 3bcvvu-NavigationLink 1rvnjg3-MenuLabel wwu7f1-MenuLabel 1jhq4ui-IconWrapper xx6wca-GlobalNavigationSide 1tmabzc-IconWrapper 1hhm2vt-SearchText ukdf5s-Menu b4jczx-MenuWrapper 4jsrm8-MenuLinkList-En 1siiay3-MenuLink 1jj3sws-Button 1a1fy59-IconWrapper a9z41e-ProductNavigationContainer wmb5oz-Masthead 12x0ma7-ContentWrapper 1vyfvn-LogoLink t7pnqp-Logo 1kstjkj-Navigation 1rsjpl7-MainNavBarContainer wq2axq-MenuContainer-PrimaryNavBarContainer 17vmgpw-PrimaryListContainer 99wfvh-ToggleContainer wbp1xc-StyledToggle 1m4972l-IconWrapper 1giv6qp-MenuListContainer 4oc13c-StyledMenuList jgj25b-StyledMenuItem 79yz40-StyledLink 1cr0snw-LinkTextContainer r71w23-StyledLink 1wo12qm-ToggleContainer 1gc2tn4-MenuContainer-MoreMenuWrapper 6tbwbt-MoreMenuListContainer lnnv4y-MenuListContainer 151n6oh-StyledMenuList arep0q-StyledMenuItem 1hs310q-StyledLink 11roo6y-LinkTextContainer 150dx44-MenuContainer-SecondaryNavBarContainer 1jvl6kx-MenuListContainer afn8hf-StyledMenuList 1vcsos0-StyledMenuItem 1l10saa-StyledLink tc9bxr-LinkTextContainer 1339fg2-StyledLink 1n8l1hq-MainSection wr17qi-ContainerWithSidebarWrapper rgov1k-MainColumn 5h7eao-ArticleWrapper 18mgjmu-HeadingWrapper 1pl2zfy-StyledHeading 1c3ha30-MetadataStrip 8d0yke-MetadataStripItem m5j4pi-MetadataContent 8g95ls-MetadataSnippet 1cyelkp-IconContainer xa24e7-TagShareWrapper 1ynay8h-StyledInformationPanel 1x6pwo0-Button 1m1yjg2-StyledPanelContent 1u4rjjc-CloseButtonWrapper qwgw1p-Button 13wc71o-PanelWrapper k1ekdk-StyledTitleArea 1wtolw8-Button xwi91l-IconWrapper gs1xzq-StyledLink vk3nhx-ComponentWrapper 1pvhdts-StyledFigure ab5fd8-StyledFigureContainer 1xtcmof-Placeholder 1drmwog-Image 1ecljvk-StyledFigureCopyright 1rnnz6t-StyledFigureCaption uf6wea-RichTextComponentWrapper 18snukc-RichTextContainer hmf8ql-BoldText 18mjolk-ComponentWrapper 1iqsg44-Placeholder mysbf6-ComponentWrapper-CrossheadComponentWrapper qozapo-StyledHeading 1pzprxn-BulletListContainer 9nsdc6-InlineLink ukwdbg-SectionWrapper bo8ols-StyledTagContainer 4c4zzp-SectionHeaderWrapper 1y8kwfd-SectionHeader 1nrzmoz-StyledHeading i7uuy0-Cluster d7aixc-ClusterItems 1yno9a1-StyledLink 1rw2j9a-Stack 1as76fj-PromoItem lr3ueg-Promo 2cexri-PromoNoImage som5se-PromoContent rjdkox-Stack 1k7ldwd-PromoLink 10zannm-PromoHeadline 1kczfdm-AsideWrapper 1aqfnou-PromoGroupWrapper j8lhkm-PromoItem 18k1qz4-Stack w0d5g8-IconContainer k2vwuw-PromoGroupWrapper 1mexmsk-PromoPortrait z60stg-PromoImageContainer 17h6w1t-PromoImageContainerInner fec6qv-ImageWrapper 1wsf921-PageTypeWrapper 1faorcu-Container pyt26q-StyledIconContainer-MediumIconContainer 1lmfp3a-Placeholder 1whgsx2-PromoGroupWrapper 4idbs4-PromoGroupWrapper sbvfw9-Stack 1g52tyu-PromoItem kgwj7-HeadlineContainer 1q3lhyn-Heading 2nuv1h-Rank 1so9cru-FooterSection e15gf1-ServiceBar 1a6riyw-ServiceBarTitle skkc29-StyledHeading 1lx08fz-ServiceLinkList 1f1i09u-StyledLink fjeiuk-StyledIconContainer 3esohe-GlobalFooter n6awjw-Stack 11iizsg-Columns 11vz0sp-Link-NavigationLink 1lgv7pe-Stack 1d0zczs-ClusterItems 8rs68s-Link-LegalLink 1xgx53b-Link">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,addr ...
# <!DOCTYPE html>
# <html class="no-js" lang="en-GB"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><title data-rh="true">South Africa's Zulu royals: Whoâs who in the fight for the throne - BBC News</title><meta content="The monarchy is plunged into controversy following the death of the king and the regent." data-rh="true" name="description"/><meta content="#FFFFFF" data-rh="true" name="theme-color"/><meta content="https://www.facebook.com/bbcnews" data-rh="true" property="article:author"/><meta content="100004154058350" data-rh="true" property="fb:admins"/><meta content="1609039196070050" data-rh="true" property="fb:app_id"/><meta content="1143803202301544,317278538359186,1392506827668140,742734325867560,185246968166196,156060587793370,137920769558355,193435954068976,21263239760,156400551056385,929399697073756,154344434967,228735667216,80758950658,260212261199,294662213128,1086451581439054,283348121682053,295830058648,239931389545417,304314573046,310719525611571,647687225371774,1159932557403143,286567251709437,1731770190373618,125309456546,163571453661989,285361880228,512423982152360,238003846549831,176663550714,260967092113,118450564909230,100978706649892,15286229625,122103087870579,120655094632228,102814153147070,124715648647,153132638110668,150467675018739" data-rh="true" property="fb:pages"/><meta content="The monarchy is plunged into controversy following the death of the king and the regent." data-rh="true" property="og:description"/><meta content="https://ichef.bbci.co.uk/news/1024/branded_news/10EEE/production/_118385396_zulu3.jpg" data-rh="true" property="og:image"/><meta content="Zulu Warriors at the funeral service of King Goodwill Zwelithini KaBhekuzulu on March 18, 2021 in Nongoma, South Africa." data-rh="true" property="og:image:alt"/><meta content="en_GB" data-rh="true" property="og:locale"/><meta content="BBC News" data-rh="true" property="og:site_name"/><meta content="South Africa's Zulu royals: Whoâs who in the fight for the throne" data-rh="true" property="og:title"/><meta content="article" data-rh="true" property="og:type"/><meta content="https://www.bbc.com/news/world-africa-56993215" data-rh="true" property="og:url"/><meta content="Africa" data-rh="true" property="article:section"/><meta content="summary_large_image" data-rh="true" name="twitter:card"/><meta content="@BBCWorld" data-rh="true" name="twitter:creator"/><meta content="The monarchy is plunged into controversy following the death of the king and the regent." data-rh="true" name="twitter:description"/><meta content="www.bbc.com" data-rh="true" name="twitter:domain"/><meta content="https://ichef.bbci.co.uk/news/1024/branded_news/10EEE/production/_118385396_zulu3.jpg" data-rh="true" name="twitter:image:src"/><meta content="Zulu Warriors at the funeral service of King Goodwill Zwelithini KaBhekuzulu on March 18, 2021 in Nongoma, South Africa." data-rh="true" name="twitter:image:alt"/><meta content="@BBCWorld" data-rh="true" name="twitter:site"/><meta content="South Africa's Zulu royals: Whoâs who in the fight for the throne" data-rh="true" name="twitter:title"/><meta content="BBC News" data-rh="true" name="application-name" type="metaTags"/><meta content="yes" data-rh="true" name="mobile-web-app-capable" type="metaTags"/><meta content="BBC News" data-rh="true" name="msapplication-TileImage" type="metaTags"/><meta content="#bb1919" data-rh="true" name="msapplication-TileColor" type="metaTags"/><meta content="on" data-rh="true" http-equiv="cleartype" name="cleartype" type="metaTags"/><link data-rh="true" href="https://www.bbc.com/news/world-africa-56993215" rel="canonical"/><link data-rh="true" href="https://www.bbc.com/news/world-africa-56993215.amp" rel="amphtml"/><link data-rh="true" href="https://www.bbc.co.uk/news/world-africa-56993215" hreflang="en-gb" rel="alternate"/><link data-rh="true" href="https://www.bbc.com/news/world-africa-56993215" hreflang="en" rel="alternate"/><link data-rh="true" href="https: ...
# /**
# * https://gist.github.com/samthor/64b114e4a4f539915a95b91ffd340acc
# */
# (function() {
#   var check = document.createElement('script');
#   if (!('noModule' in check) && 'onbeforeload' in check) {
#     var support = false;
#     document.addEventListener('beforeload', function(e) {
#       if (e.target === check) {
#         support = true;
#       } else if (!e.target.hasAttribute('nomodule') || !support) {
#         return;
#       }
#       e.preventDefault();
#     }, true);
#
#     check.type = 'module';
#     check.src = '.';
#     document.head.appendChild(check);
#     check.remove();
#   }
# }());
# </script><script nonce="CIzzZ6hTcyKSHesXXX1G0KjFMTvlqTZVt466dg2WcG1cXPYBMW">document.querySelector("html").classList.remove("no-js")</script><style data-emotion-css="10943lf 181c4hk-SectionWrapper 1c70a0k-HeaderSection 1wqums9-GlobalNavigation 1ocoo3l-Wrap 1va5u92-GlobalNavigationContent zfamng-GlobalNavigationSide 1m0vj5n-GlobalNavigationItem sz8ckn-NavigationLink-LogoLink 1pfj44u-LogoIconWrapper xi5oyi-StyledIcon 1f39n02-VisuallyHidden y0ubc0-AccessibilityLink vp47zn-GlobalNavigationLinkList-En d5c0hm-GlobalNavigationProduct-GlobalNavigationNonProductItem-GlobalNavigationAccount br3q78-NavigationLink-AccountLink q3rgld-AccountIconWrapper qgttmg-AccountText so3uhw-GlobalNavigationProduct 4aca3d-NavigationLink 13icshe-NavigationLink 1j1nxpl-NavigationLink 1doc5cp-NavigationLink 1g0nxtm-NavigationLink 13rbivf-NavigationLink f5m96n-NavigationLink jyg7lk-NavigationLink 3bcvvu-NavigationLink 1rvnjg3-MenuLabel wwu7f1-MenuLabel 1jhq4ui-IconWrapper xx6wca-GlobalNavigationSide 1tmabzc-IconWrapper 1hhm2vt-SearchText ukdf5s-Menu b4jczx-MenuWrapper 4jsrm8-MenuLinkList-En 1siiay3-MenuLink 1jj3sws-Button 1a1fy59-IconWrapper a9z41e-ProductNavigationContainer wmb5oz-Masthead 12x0ma7-ContentWrapper 1vyfvn-LogoLink t7pnqp-Logo 1kstjkj-Navigation 1rsjpl7-MainNavBarContainer wq2axq-MenuContainer-PrimaryNavBarContainer 17vmgpw-PrimaryListContainer 99wfvh-ToggleContainer wbp1xc-StyledToggle 1m4972l-IconWrapper 1giv6qp-MenuListContainer 4oc13c-StyledMenuList jgj25b-StyledMenuItem 79yz40-StyledLink 1cr0snw-LinkTextContainer r71w23-StyledLink 1wo12qm-ToggleContainer 1gc2tn4-MenuContainer-MoreMenuWrapper 6tbwbt-MoreMenuListContainer lnnv4y-MenuListContainer 151n6oh-StyledMenuList arep0q-StyledMenuItem 1hs310q-StyledLink 11roo6y-LinkTextContainer 150dx44-MenuContainer-SecondaryNavBarContainer 1jvl6kx-MenuListContainer afn8hf-StyledMenuList 1vcsos0-StyledMenuItem 1l10saa-StyledLink tc9bxr-LinkTextContainer 1339fg2-StyledLink 1n8l1hq-MainSection wr17qi-ContainerWithSidebarWrapper rgov1k-MainColumn 5h7eao-ArticleWrapper 18mgjmu-HeadingWrapper 1pl2zfy-StyledHeading 1c3ha30-MetadataStrip 8d0yke-MetadataStripItem m5j4pi-MetadataContent 8g95ls-MetadataSnippet 1cyelkp-IconContainer xa24e7-TagShareWrapper 1ynay8h-StyledInformationPanel 1x6pwo0-Button 1m1yjg2-StyledPanelContent 1u4rjjc-CloseButtonWrapper qwgw1p-Button 13wc71o-PanelWrapper k1ekdk-StyledTitleArea 1wtolw8-Button xwi91l-IconWrapper gs1xzq-StyledLink vk3nhx-ComponentWrapper 1pvhdts-StyledFigure ab5fd8-StyledFigureContainer 1xtcmof-Placeholder 1drmwog-Image 1ecljvk-StyledFigureCopyright 1rnnz6t-StyledFigureCaption uf6wea-RichTextComponentWrapper 18snukc-RichTextContainer hmf8ql-BoldText 18mjolk-ComponentWrapper 1iqsg44-Placeholder mysbf6-ComponentWrapper-CrossheadComponentWrapper qozapo-StyledHeading 1pzprxn-BulletListContainer 9nsdc6-InlineLink ukwdbg-SectionWrapper bo8ols-StyledTagContainer 4c4zzp-SectionHeaderWrapper 1y8kwfd-SectionHeader 1nrzmoz-StyledHeading i7uuy0-Cluster d7aixc-ClusterItems 1yno9a1-StyledLink 1rw2j9a-Stack 1as76fj-PromoItem lr3ueg-Promo 2cexri-PromoNoImage som5se-PromoContent rjdkox-Stack 1k7ldwd-PromoLink 10zannm-PromoHeadline 1kczfdm-AsideWrapper 1aqfnou-PromoGroupWrapper j8lhkm-PromoItem 18k1qz4-Stack w0d5g8-IconContainer k2vwuw-PromoGroupWrapper 1mexmsk-PromoPortrait z60stg-PromoImageContainer 17h6w1t-PromoImageContainerInner fec6qv-ImageWrapper 1wsf921-PageTypeWrapper 1faorcu-Container pyt26q-StyledIconContainer-MediumIconContainer 1lmfp3a-Placeholder 1whgsx2-PromoGroupWrapper 4idbs4-PromoGroupWrapper sbvfw9-Stack 1g52tyu-PromoItem kgwj7-HeadlineContainer 1q3lhyn-Heading 2nuv1h-Rank 1so9cru-FooterSection e15gf1-ServiceBar 1a6riyw-ServiceBarTitle skkc29-StyledHeading 1lx08fz-ServiceLinkList 1f1i09u-StyledLink fjeiuk-StyledIconContainer 3esohe-GlobalFooter n6awjw-Stack 11iizsg-Columns 11vz0sp-Link-NavigationLink 1lgv7pe-Stack 1d0zczs-ClusterItems 8rs68s-Link-LegalLink 1xgx53b-Link">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,addr ...
# ['The Zulu monarchy in South Africa has been plunged into controversy following the death of King Goodwill Zwelithini and - weeks later - the regent.', 'It has led to a vicious power struggle for the throne - royals are fighting it out in court, hurling insults in public, and fuelling rumours of the poisoning of rivals.', "The BBC's Pumza Fihlani in Johannesburg looks at some of the key players in the royal drama:", 'Born on 14 July 1948, he was the eighth monarch of the Zulu nation. Before he could take over from his father in 1971, he was forced to go into hiding for three years following death threats.', 'Isilo Samabandla Onke, loosely translated as "King of all Zulu kings", as he was called, was a direct descendent of King Cetshwayo, the leader of the Zulu nation during the 1879 war against the British army.', 'To many, the father of 28 children from six wives embodied the honouring of time-held cultural practices. A feature of his reign was the revival of Umhlanga or Reed Dance in 1991.', 'The ceremony, attended by many hundreds of young unmarried Zulu women, is meant to celebrate virginity but King Zwelithini said it was also there to promote HIV and Aids awareness in KwaZulu-Natal - a province with one of the highest HIV-infection rates in the country.', 'King Zwelithini died on 12 March in hospital where he was being treated for diabetes-related issues. He was the longest-serving Zulu monarch, having been on the throne for almost 50 years.', 'After he was interred, his will was read out at a private gathering of the royal family. It is now at the centre of major dispute within the royal family, with some royals claiming that it had been forged.', 'According to the will, the king chose her as the regent of the 11-million-strong nation.', "Queen Dlamini-Zulu was to preside over the throne throughout the three months of mourning and was expected to announce the king's successor. But she died before doing so.", "She was the sister of Eswatini's King Mswati III, and married the Zulu monarch in 1977.", 'As she came from royalty, Queen Dlamini-Zulu became the "Great Wife".  She had eight children with the late king.', "Unlike the king's other wives, her lobola, or bride price, of about 300 cattle was paid for by the Zulu nation, following a collection within communities.", 'Historians say this cemented her senior status within the royal family.', 'Her appointment as regent fuelled speculation that her eldest son, the US-educated 46-year-old Prince Misizulu, would be the next monarch, though the royal family has not confirmed this.', "The 65-year-old died from an undisclosed illness just a month after taking over as regent and is being buried on Thursday. The queen's unexpected death on 29 April has left many questions unanswered and stirred rumours of a murder plot.", 'Over the last few years she had been spending more time in Eswatini, apparently to attend to her health.', 'On one occasion, King Zwelithini, explaining her absence to the Zulu nation, said she had been poisoned.', '"The king spoke before hundreds of people in December 2017, when we gathered for the [46th] anniversary celebration of his coronation. In front of all these people, His Majesty said: \'Mnemtanenkosi has been poisoned. That is why she is not with us\'," recounted Zulu traditional prime minister Chief Mangosuthu Buthelezi in a statement earlier this week.', 'No further details are available on the poisoning claims from 2017, but it is understood that she had been in and out of hospital since then.', 'It is still unclear how she died. Chief Buthelezi said a post-mortem had been done to establish the cause of death, and its results were expected in a couple of weeks.', '"When I announced Her Majesty the regent\'s passing, I spoke in isiZulu, explaining that doctors had not wanted to operate because of toxins in her liver. This required treatment with antibiotics in the hope of reducing the infection. Toxins are not the same thing as poison," he was quot ...

# %%
doc = nlp(summary)

# %% [markdown]
# ### Tokenization

# %%
for token in doc:
    print(token.text, '--->', spacy.explain(token.text))
# Out:
# The ---> None
# Zulu ---> None
# monarchy ---> None
# in ---> None
# South ---> None
# Africa ---> None
# has ---> None
# been ---> None
# plunged ---> None
# into ---> None
# controversy ---> None
# following ---> None
# the ---> None
# death ---> None
# of ---> None
# King ---> None
# Goodwill ---> None
# Zwelithini ---> None
# and ---> None
# - ---> None
# weeks ---> None
# later ---> None
# - ---> None
# the ---> None
# regent ---> None
# . ---> punctuation mark, sentence closer
# It ---> None
# has ---> None
# led ---> None
# to ---> None
# a ---> None
# vicious ---> None
# power ---> None
# struggle ---> None
# for ---> None
# the ---> None
# throne ---> None
# - ---> None
# royals ---> None
# are ---> None
# fighting ---> None
# it ---> None
# out ---> None
# in ---> None
# court ---> None
# , ---> punctuation mark, comma
# hurling ---> None
# insults ---> None
# in ---> None
# public ---> None
# , ---> punctuation mark, comma
# and ---> None
# fuelling ---> None
# rumours ---> None
# of ---> None
# the ---> None
# poisoning ---> None
# of ---> None
# rivals ---> None
# . ---> punctuation mark, sentence closer
# Born ---> None
# on ---> None
# 14 ---> None
# July ---> None
# 1948 ---> None
# , ---> punctuation mark, comma
# he ---> None
# was ---> None
# the ---> None
# eighth ---> None
# monarch ---> None
# of ---> None
# the ---> None
# Zulu ---> None
# nation ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# She ---> None
# had ---> None
# eight ---> None
# children ---> None
# with ---> None
# the ---> None
# late ---> None
# king ---> None
# . ---> punctuation mark, sentence closer
# Unlike ---> None
# the ---> None
# king ---> None
# 's ---> None
# other ---> None
# wives ---> None
# , ---> punctuation mark, comma
# her ---> None
# lobola ---> None
# , ---> punctuation mark, comma
# or ---> None
# bride ---> None
# price ---> None
# , ---> punctuation mark, comma
# of ---> None
# about ---> None
# 300 ---> None
# cattle ---> None
# was ---> None
# paid ---> None
# for ---> None
# by ---> None
# the ---> None
# Zulu ---> None
# nation ---> None
# , ---> punctuation mark, comma
# following ---> None
# a ---> None
# collection ---> None
# within ---> None
# communities ---> None
# . ---> punctuation mark, sentence closer
# Historians ---> None
# say ---> None
# this ---> None
# cemented ---> None
# her ---> None
# senior ---> None
# status ---> None
# within ---> None
# the ---> None
# royal ---> None
# family ---> None
# . ---> punctuation mark, sentence closer
# Her ---> None
# appointment ---> None
# as ---> None
# regent ---> None
# fuelled ---> None
# speculation ---> None
# that ---> None
# her ---> None
# eldest ---> None
# son ---> None
# , ---> punctuation mark, comma
# the ---> None
# US ---> None
# - ---> None
# educated ---> None
# 46 ---> None
# - ---> None
# year ---> None
# - ---> None
# old ---> None
# Prince ---> None
# Misizulu ---> None
# , ---> punctuation mark, comma
# would ---> None
# be ---> None
# the ---> None
# next ---> None
# monarch ---> None
# , ---> punctuation mark, comma
# though ---> None
# the ---> None
# royal ---> None
# family ---> None
# has ---> None
# not ---> None
# confirmed ---> None
# this ---> None
# . ---> punctuation mark, sentence closer
# The ---> None
# 65 ---> None
# - ---> None
# year ---> None
# - ---> None
# old ---> None
# died ---> None
# from ---> None
# an ---> None
# undisclosed ---> None
# illness ---> None
# just ---> None
# a ---> None
# month ---> None
# after ---> None
# taking ---> None
# over ---> None
# as ---> None
# regent ---> None
# and ---> None
# is ---> None
# being ---> None
# buried ---> None
# on ---> None
# Thursday ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# The ---> None
# queen ---> None
# 's ---> None
# unexpected ---> None
# death ---> None
# on ---> None
# 29 ---> None
# April ---> None
# has ---> None
# left ---> None
# many ---> None
# questions ---> None
# unanswered ---> None
# and ---> None
# stirred ---> None
# rumours ---> None
# of ---> None
# a ---> None
# murder ---> None
# plot ---> None
# . ---> punctuation mark, sentence closer
# Over ---> None
# the ---> None
# last ---> None
# few ---> None
# years ---> None
# she ---> None
# had ---> None
# been ---> None
# spending ---> None
# more ---> None
# time ---> None
# in ---> None
# Eswatini ---> None
# , ---> punctuation mark, comma
# apparently ---> None
# to ---> None
# attend ---> None
# to ---> None
# her ---> None
# health ---> None
# . ---> punctuation mark, sentence closer
# On ---> None
# one ---> None
# occasion ---> None
# , ---> punctuation mark, comma
# King ---> None
# Zwelithini ---> None
# , ---> punctuation mark, comma
# explaining ---> None
# her ---> None
# absence ---> None
# to ---> None
# the ---> None
# Zulu ---> None
# nation ---> None
# , ---> punctuation mark, comma
# said ---> None
# she ---> None
# had ---> None
# been ---> None
# poisoned ---> None
# . ---> punctuation mark, sentence closer
# "The ---> None
# king ---> None
# spoke ---> None
# before ---> None
# hundreds ---> None
# of ---> None
# people ---> None
# in ---> None
# December ---> None
# 2017 ---> None
# , ---> punctuation mark, comma
# when ---> None
# we ---> None
# gathered ---> None
# for ---> None
# the ---> None
# [ ---> None
# 46th ---> None
# ] ---> None
# anniversary ---> None
# celebration ---> None
# of ---> None
# his ---> None
# coronation ---> None
# . ---> punctuation mark, sentence closer

# %% [markdown]
# ## POS Parsing

# %%
for token in doc:
    print(token.text, '--->', token.pos_, '--->', spacy.explain(token.pos_))
# Out:
# The ---> DET ---> determiner
# Zulu ---> PROPN ---> proper noun
# monarchy ---> NOUN ---> noun
# in ---> ADP ---> adposition
# South ---> PROPN ---> proper noun
# Africa ---> PROPN ---> proper noun
# has ---> AUX ---> auxiliary
# been ---> AUX ---> auxiliary
# plunged ---> VERB ---> verb
# into ---> ADP ---> adposition
# controversy ---> NOUN ---> noun
# following ---> VERB ---> verb
# the ---> DET ---> determiner
# death ---> NOUN ---> noun
# of ---> ADP ---> adposition
# King ---> PROPN ---> proper noun
# Goodwill ---> PROPN ---> proper noun
# Zwelithini ---> PROPN ---> proper noun
# and ---> CCONJ ---> coordinating conjunction
# - ---> PUNCT ---> punctuation
# weeks ---> NOUN ---> noun
# later ---> ADV ---> adverb
# - ---> PUNCT ---> punctuation
# the ---> DET ---> determiner
# regent ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# It ---> PRON ---> pronoun
# has ---> AUX ---> auxiliary
# led ---> VERB ---> verb
# to ---> ADP ---> adposition
# a ---> DET ---> determiner
# vicious ---> ADJ ---> adjective
# power ---> NOUN ---> noun
# struggle ---> NOUN ---> noun
# for ---> ADP ---> adposition
# the ---> DET ---> determiner
# throne ---> NOUN ---> noun
# - ---> PUNCT ---> punctuation
# royals ---> NOUN ---> noun
# are ---> AUX ---> auxiliary
# fighting ---> VERB ---> verb
# it ---> PRON ---> pronoun
# out ---> ADP ---> adposition
# in ---> ADP ---> adposition
# court ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# hurling ---> VERB ---> verb
# insults ---> NOUN ---> noun
# in ---> ADP ---> adposition
# public ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# and ---> CCONJ ---> coordinating conjunction
# fuelling ---> VERB ---> verb
# rumours ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# poisoning ---> NOUN ---> noun
# of ---> ADP ---> adposition
# rivals ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# Born ---> VERB ---> verb
# on ---> ADP ---> adposition
# 14 ---> NUM ---> numeral
# July ---> PROPN ---> proper noun
# 1948 ---> NUM ---> numeral
# , ---> PUNCT ---> punctuation
# he ---> PRON ---> pronoun
# was ---> AUX ---> auxiliary
# the ---> DET ---> determiner
# eighth ---> ADJ ---> adjective
# monarch ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# Zulu ---> PROPN ---> proper noun
# nation ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# She ---> PRON ---> pronoun
# had ---> VERB ---> verb
# eight ---> NUM ---> numeral
# children ---> NOUN ---> noun
# with ---> ADP ---> adposition
# the ---> DET ---> determiner
# late ---> ADJ ---> adjective
# king ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# Unlike ---> ADP ---> adposition
# the ---> DET ---> determiner
# king ---> NOUN ---> noun
# 's ---> PART ---> particle
# other ---> ADJ ---> adjective
# wives ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# her ---> PRON ---> pronoun
# lobola ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# or ---> CCONJ ---> coordinating conjunction
# bride ---> NOUN ---> noun
# price ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# of ---> ADP ---> adposition
# about ---> ADV ---> adverb
# 300 ---> NUM ---> numeral
# cattle ---> NOUN ---> noun
# was ---> AUX ---> auxiliary
# paid ---> VERB ---> verb
# for ---> ADP ---> adposition
# by ---> ADP ---> adposition
# the ---> DET ---> determiner
# Zulu ---> PROPN ---> proper noun
# nation ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# following ---> VERB ---> verb
# a ---> DET ---> determiner
# collection ---> NOUN ---> noun
# within ---> ADP ---> adposition
# communities ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# Historians ---> NOUN ---> noun
# say ---> VERB ---> verb
# this ---> DET ---> determiner
# cemented ---> VERB ---> verb
# her ---> PRON ---> pronoun
# senior ---> ADJ ---> adjective
# status ---> NOUN ---> noun
# within ---> ADP ---> adposition
# the ---> DET ---> determiner
# royal ---> ADJ ---> adjective
# family ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# Her ---> PRON ---> pronoun
# appointment ---> NOUN ---> noun
# as ---> ADP ---> adposition
# regent ---> ADJ ---> adjective
# fuelled ---> ADJ ---> adjective
# speculation ---> NOUN ---> noun
# that ---> SCONJ ---> subordinating conjunction
# her ---> PRON ---> pronoun
# eldest ---> ADJ ---> adjective
# son ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# the ---> DET ---> determiner
# US ---> PROPN ---> proper noun
# - ---> PUNCT ---> punctuation
# educated ---> VERB ---> verb
# 46 ---> NUM ---> numeral
# - ---> PUNCT ---> punctuation
# year ---> NOUN ---> noun
# - ---> PUNCT ---> punctuation
# old ---> ADJ ---> adjective
# Prince ---> PROPN ---> proper noun
# Misizulu ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# would ---> AUX ---> auxiliary
# be ---> VERB ---> verb
# the ---> DET ---> determiner
# next ---> ADJ ---> adjective
# monarch ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# though ---> SCONJ ---> subordinating conjunction
# the ---> DET ---> determiner
# royal ---> ADJ ---> adjective
# family ---> NOUN ---> noun
# has ---> AUX ---> auxiliary
# not ---> PART ---> particle
# confirmed ---> VERB ---> verb
# this ---> DET ---> determiner
# . ---> PUNCT ---> punctuation
# The ---> DET ---> determiner
# 65 ---> NUM ---> numeral
# - ---> PUNCT ---> punctuation
# year ---> NOUN ---> noun
# - ---> PUNCT ---> punctuation
# old ---> ADJ ---> adjective
# died ---> VERB ---> verb
# from ---> ADP ---> adposition
# an ---> DET ---> determiner
# undisclosed ---> ADJ ---> adjective
# illness ---> NOUN ---> noun
# just ---> ADV ---> adverb
# a ---> DET ---> determiner
# month ---> NOUN ---> noun
# after ---> ADP ---> adposition
# taking ---> VERB ---> verb
# over ---> ADP ---> adposition
# as ---> ADP ---> adposition
# regent ---> ADJ ---> adjective
# and ---> CCONJ ---> coordinating conjunction
# is ---> AUX ---> auxiliary
# being ---> AUX ---> auxiliary
# buried ---> VERB ---> verb
# on ---> ADP ---> adposition
# Thursday ---> PROPN ---> proper noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# The ---> DET ---> determiner
# queen ---> NOUN ---> noun
# 's ---> PART ---> particle
# unexpected ---> ADJ ---> adjective
# death ---> NOUN ---> noun
# on ---> ADP ---> adposition
# 29 ---> NUM ---> numeral
# April ---> PROPN ---> proper noun
# has ---> AUX ---> auxiliary
# left ---> VERB ---> verb
# many ---> ADJ ---> adjective
# questions ---> NOUN ---> noun
# unanswered ---> ADJ ---> adjective
# and ---> CCONJ ---> coordinating conjunction
# stirred ---> VERB ---> verb
# rumours ---> NOUN ---> noun
# of ---> ADP ---> adposition
# a ---> DET ---> determiner
# murder ---> NOUN ---> noun
# plot ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# Over ---> ADP ---> adposition
# the ---> DET ---> determiner
# last ---> ADJ ---> adjective
# few ---> ADJ ---> adjective
# years ---> NOUN ---> noun
# she ---> PRON ---> pronoun
# had ---> AUX ---> auxiliary
# been ---> AUX ---> auxiliary
# spending ---> VERB ---> verb
# more ---> ADJ ---> adjective
# time ---> NOUN ---> noun
# in ---> ADP ---> adposition
# Eswatini ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# apparently ---> ADV ---> adverb
# to ---> PART ---> particle
# attend ---> VERB ---> verb
# to ---> ADP ---> adposition
# her ---> PRON ---> pronoun
# health ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# On ---> ADP ---> adposition
# one ---> NUM ---> numeral
# occasion ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# King ---> PROPN ---> proper noun
# Zwelithini ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# explaining ---> VERB ---> verb
# her ---> PRON ---> pronoun
# absence ---> NOUN ---> noun
# to ---> ADP ---> adposition
# the ---> DET ---> determiner
# Zulu ---> PROPN ---> proper noun
# nation ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# said ---> VERB ---> verb
# she ---> PRON ---> pronoun
# had ---> AUX ---> auxiliary
# been ---> AUX ---> auxiliary
# poisoned ---> VERB ---> verb
# . ---> PUNCT ---> punctuation
# "The ---> DET ---> determiner
# king ---> NOUN ---> noun
# spoke ---> VERB ---> verb
# before ---> ADP ---> adposition
# hundreds ---> NOUN ---> noun
# of ---> ADP ---> adposition
# people ---> NOUN ---> noun
# in ---> ADP ---> adposition
# December ---> PROPN ---> proper noun
# 2017 ---> NUM ---> numeral
# , ---> PUNCT ---> punctuation
# when ---> ADV ---> adverb
# we ---> PRON ---> pronoun
# gathered ---> VERB ---> verb
# for ---> ADP ---> adposition
# the ---> DET ---> determiner
# [ ---> PUNCT ---> punctuation
# 46th ---> ADJ ---> adjective
# ] ---> PUNCT ---> punctuation
# anniversary ---> NOUN ---> noun
# celebration ---> NOUN ---> noun
# of ---> ADP ---> adposition
# his ---> PRON ---> pronoun
# coronation ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation

# %% [markdown]
# ## Dependency Parsing

# %%
for token in doc:
    print(token.text, '--->', token.dep_, '--->', spacy.explain(token.dep))
# Out:
# The ---> det ---> None
# Zulu ---> compound ---> None
# monarchy ---> nsubjpass ---> None
# in ---> prep ---> None
# South ---> compound ---> None
# Africa ---> pobj ---> None
# has ---> aux ---> None
# been ---> auxpass ---> None
# plunged ---> ROOT ---> None
# into ---> prep ---> None
# controversy ---> pobj ---> None
# following ---> prep ---> None
# the ---> det ---> None
# death ---> pobj ---> None
# of ---> prep ---> None
# King ---> compound ---> None
# Goodwill ---> compound ---> None
# Zwelithini ---> pobj ---> None
# and ---> cc ---> None
# - ---> punct ---> None
# weeks ---> conj ---> None
# later ---> advmod ---> None
# - ---> punct ---> None
# the ---> det ---> None
# regent ---> oprd ---> None
# . ---> punct ---> None
# It ---> nsubj ---> None
# has ---> aux ---> None
# led ---> ROOT ---> None
# to ---> prep ---> None
# a ---> det ---> None
# vicious ---> amod ---> None
# power ---> compound ---> None
# struggle ---> pobj ---> None
# for ---> prep ---> None
# the ---> det ---> None
# throne ---> compound ---> None
# - ---> punct ---> None
# royals ---> pobj ---> None
# are ---> aux ---> None
# fighting ---> ccomp ---> None
# it ---> dobj ---> None
# out ---> prt ---> None
# in ---> prep ---> None
# court ---> pobj ---> None
# , ---> punct ---> None
# hurling ---> advcl ---> None
# insults ---> dobj ---> None
# in ---> prep ---> None
# public ---> pobj ---> None
# , ---> punct ---> None
# and ---> cc ---> None
# fuelling ---> conj ---> None
# rumours ---> dobj ---> None
# of ---> prep ---> None
# the ---> det ---> None
# poisoning ---> pobj ---> None
# of ---> prep ---> None
# rivals ---> pobj ---> None
# . ---> punct ---> None
# Born ---> advcl ---> None
# on ---> prep ---> None
# 14 ---> nummod ---> None
# July ---> pobj ---> None
# 1948 ---> nummod ---> None
# , ---> punct ---> None
# he ---> nsubj ---> None
# was ---> ROOT ---> None
# the ---> det ---> None
# eighth ---> amod ---> None
# monarch ---> attr ---> None
# of ---> prep ---> None
# the ---> det ---> None
# Zulu ---> compound ---> None
# nation ---> pobj ---> None
# . ---> punct ---> None
#
#  ---> ROOT ---> None
# She ---> nsubj ---> None
# had ---> ROOT ---> None
# eight ---> nummod ---> None
# children ---> dobj ---> None
# with ---> prep ---> None
# the ---> det ---> None
# late ---> amod ---> None
# king ---> pobj ---> None
# . ---> punct ---> None
# Unlike ---> prep ---> None
# the ---> det ---> None
# king ---> poss ---> None
# 's ---> case ---> None
# other ---> amod ---> None
# wives ---> pobj ---> None
# , ---> punct ---> None
# her ---> poss ---> None
# lobola ---> conj ---> None
# , ---> punct ---> None
# or ---> cc ---> None
# bride ---> compound ---> None
# price ---> conj ---> None
# , ---> punct ---> None
# of ---> prep ---> None
# about ---> advmod ---> None
# 300 ---> nummod ---> None
# cattle ---> pobj ---> None
# was ---> auxpass ---> None
# paid ---> ROOT ---> None
# for ---> prep ---> None
# by ---> agent ---> None
# the ---> det ---> None
# Zulu ---> compound ---> None
# nation ---> pobj ---> None
# , ---> punct ---> None
# following ---> prep ---> None
# a ---> det ---> None
# collection ---> pobj ---> None
# within ---> prep ---> None
# communities ---> pobj ---> None
# . ---> punct ---> None
# Historians ---> nsubj ---> None
# say ---> ROOT ---> None
# this ---> nsubj ---> None
# cemented ---> ccomp ---> None
# her ---> poss ---> None
# senior ---> amod ---> None
# status ---> dobj ---> None
# within ---> prep ---> None
# the ---> det ---> None
# royal ---> amod ---> None
# family ---> pobj ---> None
# . ---> punct ---> None
# Her ---> poss ---> None
# appointment ---> ROOT ---> None
# as ---> prep ---> None
# regent ---> amod ---> None
# fuelled ---> amod ---> None
# speculation ---> pobj ---> None
# that ---> mark ---> None
# her ---> poss ---> None
# eldest ---> amod ---> None
# son ---> nsubj ---> None
# , ---> punct ---> None
# the ---> det ---> None
# US ---> npadvmod ---> None
# - ---> punct ---> None
# educated ---> amod ---> None
# 46 ---> nummod ---> None
# - ---> punct ---> None
# year ---> npadvmod ---> None
# - ---> punct ---> None
# old ---> amod ---> None
# Prince ---> compound ---> None
# Misizulu ---> appos ---> None
# , ---> punct ---> None
# would ---> aux ---> None
# be ---> acl ---> None
# the ---> det ---> None
# next ---> amod ---> None
# monarch ---> attr ---> None
# , ---> punct ---> None
# though ---> mark ---> None
# the ---> det ---> None
# royal ---> amod ---> None
# family ---> nsubj ---> None
# has ---> aux ---> None
# not ---> neg ---> None
# confirmed ---> advcl ---> None
# this ---> dobj ---> None
# . ---> punct ---> None
# The ---> det ---> None
# 65 ---> nummod ---> None
# - ---> punct ---> None
# year ---> npadvmod ---> None
# - ---> punct ---> None
# old ---> nsubj ---> None
# died ---> ROOT ---> None
# from ---> prep ---> None
# an ---> det ---> None
# undisclosed ---> amod ---> None
# illness ---> pobj ---> None
# just ---> advmod ---> None
# a ---> det ---> None
# month ---> npadvmod ---> None
# after ---> prep ---> None
# taking ---> pcomp ---> None
# over ---> prt ---> None
# as ---> prep ---> None
# regent ---> pobj ---> None
# and ---> cc ---> None
# is ---> aux ---> None
# being ---> auxpass ---> None
# buried ---> conj ---> None
# on ---> prep ---> None
# Thursday ---> pobj ---> None
# . ---> punct ---> None
#
#  ---> ROOT ---> None
# The ---> det ---> None
# queen ---> poss ---> None
# 's ---> case ---> None
# unexpected ---> amod ---> None
# death ---> nsubj ---> None
# on ---> prep ---> None
# 29 ---> nummod ---> None
# April ---> pobj ---> None
# has ---> aux ---> None
# left ---> ROOT ---> None
# many ---> amod ---> None
# questions ---> dobj ---> None
# unanswered ---> amod ---> None
# and ---> cc ---> None
# stirred ---> conj ---> None
# rumours ---> dobj ---> None
# of ---> prep ---> None
# a ---> det ---> None
# murder ---> compound ---> None
# plot ---> pobj ---> None
# . ---> punct ---> None
# Over ---> prep ---> None
# the ---> det ---> None
# last ---> amod ---> None
# few ---> amod ---> None
# years ---> pobj ---> None
# she ---> nsubj ---> None
# had ---> aux ---> None
# been ---> aux ---> None
# spending ---> ROOT ---> None
# more ---> amod ---> None
# time ---> dobj ---> None
# in ---> prep ---> None
# Eswatini ---> pobj ---> None
# , ---> punct ---> None
# apparently ---> advmod ---> None
# to ---> aux ---> None
# attend ---> advcl ---> None
# to ---> prep ---> None
# her ---> poss ---> None
# health ---> pobj ---> None
# . ---> punct ---> None
# On ---> prep ---> None
# one ---> nummod ---> None
# occasion ---> pobj ---> None
# , ---> punct ---> None
# King ---> compound ---> None
# Zwelithini ---> nsubj ---> None
# , ---> punct ---> None
# explaining ---> advcl ---> None
# her ---> poss ---> None
# absence ---> dobj ---> None
# to ---> prep ---> None
# the ---> det ---> None
# Zulu ---> compound ---> None
# nation ---> pobj ---> None
# , ---> punct ---> None
# said ---> ROOT ---> None
# she ---> nsubjpass ---> None
# had ---> aux ---> None
# been ---> auxpass ---> None
# poisoned ---> ccomp ---> None
# . ---> punct ---> None
# "The ---> det ---> None
# king ---> nsubj ---> None
# spoke ---> ROOT ---> None
# before ---> prep ---> None
# hundreds ---> pobj ---> None
# of ---> prep ---> None
# people ---> pobj ---> None
# in ---> prep ---> None
# December ---> pobj ---> None
# 2017 ---> nummod ---> None
# , ---> punct ---> None
# when ---> advmod ---> None
# we ---> nsubj ---> None
# gathered ---> advcl ---> None
# for ---> prep ---> None
# the ---> det ---> None
# [ ---> punct ---> None
# 46th ---> amod ---> None
# ] ---> punct ---> None
# anniversary ---> compound ---> None
# celebration ---> pobj ---> None
# of ---> prep ---> None
# his ---> poss ---> None
# coronation ---> pobj ---> None
# . ---> punct ---> None

# %% [markdown]
# ### Lemmatization

# %%
for token in doc:
    print(token.text, '--->', token.lemma_, '--->', spacy.explain(token.lemma))
# Out:
# The ---> the ---> None
# Zulu ---> Zulu ---> None
# monarchy ---> monarchy ---> None
# in ---> in ---> None
# South ---> South ---> None
# Africa ---> Africa ---> None
# has ---> have ---> None
# been ---> be ---> None
# plunged ---> plunge ---> None
# into ---> into ---> None
# controversy ---> controversy ---> None
# following ---> follow ---> None
# the ---> the ---> None
# death ---> death ---> None
# of ---> of ---> None
# King ---> King ---> None
# Goodwill ---> Goodwill ---> None
# Zwelithini ---> Zwelithini ---> None
# and ---> and ---> None
# - ---> - ---> None
# weeks ---> week ---> None
# later ---> later ---> None
# - ---> - ---> None
# the ---> the ---> None
# regent ---> regent ---> None
# . ---> . ---> None
# It ---> it ---> None
# has ---> have ---> None
# led ---> lead ---> None
# to ---> to ---> None
# a ---> a ---> None
# vicious ---> vicious ---> None
# power ---> power ---> None
# struggle ---> struggle ---> None
# for ---> for ---> None
# the ---> the ---> None
# throne ---> throne ---> None
# - ---> - ---> None
# royals ---> royal ---> None
# are ---> be ---> None
# fighting ---> fight ---> None
# it ---> it ---> None
# out ---> out ---> None
# in ---> in ---> None
# court ---> court ---> None
# , ---> , ---> None
# hurling ---> hurl ---> None
# insults ---> insult ---> None
# in ---> in ---> None
# public ---> public ---> None
# , ---> , ---> None
# and ---> and ---> None
# fuelling ---> fuel ---> None
# rumours ---> rumour ---> None
# of ---> of ---> None
# the ---> the ---> None
# poisoning ---> poisoning ---> None
# of ---> of ---> None
# rivals ---> rival ---> None
# . ---> . ---> None
# Born ---> bear ---> None
# on ---> on ---> None
# 14 ---> 14 ---> None
# July ---> July ---> None
# 1948 ---> 1948 ---> None
# , ---> , ---> None
# he ---> he ---> None
# was ---> be ---> None
# the ---> the ---> None
# eighth ---> eighth ---> None
# monarch ---> monarch ---> None
# of ---> of ---> None
# the ---> the ---> None
# Zulu ---> Zulu ---> None
# nation ---> nation ---> None
# . ---> . ---> None
#
#  --->
#  ---> None
# She ---> she ---> None
# had ---> have ---> None
# eight ---> eight ---> None
# children ---> child ---> None
# with ---> with ---> None
# the ---> the ---> None
# late ---> late ---> None
# king ---> king ---> None
# . ---> . ---> None
# Unlike ---> unlike ---> None
# the ---> the ---> None
# king ---> king ---> None
# 's ---> 's ---> None
# other ---> other ---> None
# wives ---> wife ---> None
# , ---> , ---> None
# her ---> her ---> None
# lobola ---> lobola ---> None
# , ---> , ---> None
# or ---> or ---> None
# bride ---> bride ---> None
# price ---> price ---> None
# , ---> , ---> None
# of ---> of ---> None
# about ---> about ---> None
# 300 ---> 300 ---> None
# cattle ---> cattle ---> None
# was ---> be ---> None
# paid ---> pay ---> None
# for ---> for ---> None
# by ---> by ---> None
# the ---> the ---> None
# Zulu ---> Zulu ---> None
# nation ---> nation ---> None
# , ---> , ---> None
# following ---> follow ---> None
# a ---> a ---> None
# collection ---> collection ---> None
# within ---> within ---> None
# communities ---> community ---> None
# . ---> . ---> None
# Historians ---> historian ---> None
# say ---> say ---> None
# this ---> this ---> None
# cemented ---> cement ---> None
# her ---> her ---> None
# senior ---> senior ---> None
# status ---> status ---> None
# within ---> within ---> None
# the ---> the ---> None
# royal ---> royal ---> None
# family ---> family ---> None
# . ---> . ---> None
# Her ---> her ---> None
# appointment ---> appointment ---> None
# as ---> as ---> None
# regent ---> regent ---> None
# fuelled ---> fuelled ---> None
# speculation ---> speculation ---> None
# that ---> that ---> None
# her ---> her ---> None
# eldest ---> eld ---> None
# son ---> son ---> None
# , ---> , ---> None
# the ---> the ---> None
# US ---> US ---> None
# - ---> - ---> None
# educated ---> educate ---> None
# 46 ---> 46 ---> None
# - ---> - ---> None
# year ---> year ---> None
# - ---> - ---> None
# old ---> old ---> None
# Prince ---> Prince ---> None
# Misizulu ---> Misizulu ---> None
# , ---> , ---> None
# would ---> would ---> None
# be ---> be ---> None
# the ---> the ---> None
# next ---> next ---> None
# monarch ---> monarch ---> None
# , ---> , ---> None
# though ---> though ---> None
# the ---> the ---> None
# royal ---> royal ---> None
# family ---> family ---> None
# has ---> have ---> None
# not ---> not ---> None
# confirmed ---> confirm ---> None
# this ---> this ---> None
# . ---> . ---> None
# The ---> the ---> None
# 65 ---> 65 ---> None
# - ---> - ---> None
# year ---> year ---> None
# - ---> - ---> None
# old ---> old ---> None
# died ---> die ---> None
# from ---> from ---> None
# an ---> an ---> None
# undisclosed ---> undisclosed ---> None
# illness ---> illness ---> None
# just ---> just ---> None
# a ---> a ---> None
# month ---> month ---> None
# after ---> after ---> None
# taking ---> take ---> None
# over ---> over ---> None
# as ---> as ---> None
# regent ---> regent ---> None
# and ---> and ---> None
# is ---> be ---> None
# being ---> be ---> None
# buried ---> bury ---> None
# on ---> on ---> None
# Thursday ---> Thursday ---> None
# . ---> . ---> None
#
#  --->
#  ---> None
# The ---> the ---> None
# queen ---> queen ---> None
# 's ---> 's ---> None
# unexpected ---> unexpected ---> None
# death ---> death ---> None
# on ---> on ---> None
# 29 ---> 29 ---> None
# April ---> April ---> None
# has ---> have ---> None
# left ---> leave ---> None
# many ---> many ---> None
# questions ---> question ---> None
# unanswered ---> unanswered ---> None
# and ---> and ---> None
# stirred ---> stir ---> None
# rumours ---> rumour ---> None
# of ---> of ---> None
# a ---> a ---> None
# murder ---> murder ---> None
# plot ---> plot ---> None
# . ---> . ---> None
# Over ---> over ---> None
# the ---> the ---> None
# last ---> last ---> None
# few ---> few ---> None
# years ---> year ---> None
# she ---> she ---> None
# had ---> have ---> None
# been ---> be ---> None
# spending ---> spend ---> None
# more ---> more ---> None
# time ---> time ---> None
# in ---> in ---> None
# Eswatini ---> Eswatini ---> None
# , ---> , ---> None
# apparently ---> apparently ---> None
# to ---> to ---> None
# attend ---> attend ---> None
# to ---> to ---> None
# her ---> her ---> None
# health ---> health ---> None
# . ---> . ---> None
# On ---> on ---> None
# one ---> one ---> None
# occasion ---> occasion ---> None
# , ---> , ---> None
# King ---> King ---> None
# Zwelithini ---> Zwelithini ---> None
# , ---> , ---> None
# explaining ---> explain ---> None
# her ---> her ---> None
# absence ---> absence ---> None
# to ---> to ---> None
# the ---> the ---> None
# Zulu ---> Zulu ---> None
# nation ---> nation ---> None
# , ---> , ---> None
# said ---> say ---> None
# she ---> she ---> None
# had ---> have ---> None
# been ---> be ---> None
# poisoned ---> poison ---> None
# . ---> . ---> None
# "The ---> "the ---> None
# king ---> king ---> None
# spoke ---> speak ---> None
# before ---> before ---> None
# hundreds ---> hundred ---> None
# of ---> of ---> None
# people ---> people ---> None
# in ---> in ---> None
# December ---> December ---> None
# 2017 ---> 2017 ---> None
# , ---> , ---> None
# when ---> when ---> None
# we ---> we ---> None
# gathered ---> gather ---> None
# for ---> for ---> None
# the ---> the ---> None
# [ ---> [ ---> None
# 46th ---> 46th ---> None
# ] ---> ] ---> None
# anniversary ---> anniversary ---> None
# celebration ---> celebration ---> None
# of ---> of ---> None
# his ---> his ---> None
# coronation ---> coronation ---> None
# . ---> . ---> None

# %% [markdown]
# #### Sentence boundary detection

# %%
list(doc.sents)
# Out:
# [The Zulu monarchy in South Africa has been plunged into controversy following the death of King Goodwill Zwelithini and - weeks later - the regent.,
#  It has led to a vicious power struggle for the throne - royals are fighting it out in court, hurling insults in public, and fuelling rumours of the poisoning of rivals.,
#  Born on 14 July 1948, he was the eighth monarch of the Zulu nation.,
#  ,
#  She had eight children with the late king.,
#  Unlike the king's other wives, her lobola, or bride price, of about 300 cattle was paid for by the Zulu nation, following a collection within communities.,
#  Historians say this cemented her senior status within the royal family.,
#  Her appointment as regent fuelled speculation that her eldest son, the US-educated 46-year-old Prince Misizulu, would be the next monarch, though the royal family has not confirmed this.,
#  The 65-year-old died from an undisclosed illness just a month after taking over as regent and is being buried on Thursday.,
#  ,
#  The queen's unexpected death on 29 April has left many questions unanswered and stirred rumours of a murder plot.,
#  Over the last few years she had been spending more time in Eswatini, apparently to attend to her health.,
#  On one occasion, King Zwelithini, explaining her absence to the Zulu nation, said she had been poisoned.,
#  "The king spoke before hundreds of people in December 2017, when we gathered for the [46th] anniversary celebration of his coronation.]

# %%
sentences = list(doc.sents)

# %%
for sentence in sentences:
    print(sentence)
# Out:
# The Zulu monarchy in South Africa has been plunged into controversy following the death of King Goodwill Zwelithini and - weeks later - the regent.
# It has led to a vicious power struggle for the throne - royals are fighting it out in court, hurling insults in public, and fuelling rumours of the poisoning of rivals.
# Born on 14 July 1948, he was the eighth monarch of the Zulu nation.
#
#
# She had eight children with the late king.
# Unlike the king's other wives, her lobola, or bride price, of about 300 cattle was paid for by the Zulu nation, following a collection within communities.
# Historians say this cemented her senior status within the royal family.
# Her appointment as regent fuelled speculation that her eldest son, the US-educated 46-year-old Prince Misizulu, would be the next monarch, though the royal family has not confirmed this.
# The 65-year-old died from an undisclosed illness just a month after taking over as regent and is being buried on Thursday.
#
#
# The queen's unexpected death on 29 April has left many questions unanswered and stirred rumours of a murder plot.
# Over the last few years she had been spending more time in Eswatini, apparently to attend to her health.
# On one occasion, King Zwelithini, explaining her absence to the Zulu nation, said she had been poisoned.
# "The king spoke before hundreds of people in December 2017, when we gathered for the [46th] anniversary celebration of his coronation.

# %% [markdown]
# ## Named Entity

# %%
for ent in doc.ents:
    print(ent.text, '---->', ent.label, '---->', spacy.explain(ent.label))
# Out:
# Zulu ----> 384 ----> None
# South Africa ----> 384 ----> None
# Goodwill Zwelithini ----> 380 ----> None
# 14 July 1948 ----> 391 ----> None
# eighth ----> 396 ----> None
# Zulu ----> 380 ----> None
# eight ----> 397 ----> None
# about 300 ----> 397 ----> None
# Zulu ----> 380 ----> None
# US ----> 384 ----> None
# 46-year-old ----> 391 ----> None
# Prince Misizulu ----> 380 ----> None
# 65-year-old ----> 391 ----> None
# Thursday ----> 391 ----> None
# 29 April ----> 391 ----> None
# the last few years ----> 391 ----> None
# Eswatini ----> 383 ----> None
# one ----> 397 ----> None
# King Zwelithini ----> 380 ----> None
# Zulu ----> 380 ----> None
# hundreds ----> 397 ----> None
# December 2017 ----> 391 ----> None
# 46th ----> 396 ----> None

# %% [markdown]
# ## Visualization

# %%
from spacy import displacy

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zulu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  monarchy in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     South Africa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has been plunged into controversy following the death of King
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Goodwill Zwelithini
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and - weeks later - the regent.It has led to a vicious power struggle for the throne - royals are fighting it out in court, hurling insults in public, and fuelling rumours of the poisoning of rivals.Born on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14 July 1948
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , he was the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eighth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  monarch of the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zulu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  nation.</br>She had
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  children with the late king.Unlike the king's other wives, her lobola, or bride price, of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 300
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  cattle was paid for by the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zulu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  nation, following a collection within communities.Historians say this cemented her senior status within the royal family.Her appointment as regent fuelled speculation that her eldest son, the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -educated
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     46-year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prince Misizulu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , would be the next monarch, though the royal family has not confirmed this.The
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     65-year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  died from an undisclosed illness just a month after taking over as regent and is being buried on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br>The queen's unexpected death on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29 April
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  has left many questions unanswered and stirred rumours of a murder plot.Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last few years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  she had been spending more time in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eswatini
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , apparently to attend to her health.On
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  occasion,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     King Zwelithini
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , explaining her absence to the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zulu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  nation, said she had been poisoned.&quot;The king spoke before
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hundreds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of people in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     December 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , when we gathered for the [
# <mark class

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cf1b742d1fbd48c28133f3ffef84dbac-0" class="displacy" width="43100" height="1362.0" direction="ltr" style="max-width: none; height: 1362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Zulu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">monarchy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">South</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Africa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">plunged</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">controversy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">following</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">death</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">King</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Goodwill</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Zwelithini</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">and -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">weeks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">later -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">regent.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">led</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">vicious</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">power</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">struggle</tspan>
#     <tspan class

# %% [markdown]
# #### Putting it all together

# %%
lis = []

# %%
for token in doc:
    dic = {}
    dic['Token'] = token.text
    dic['POS'] = token.pos_
    dic['Tags'] = token.tag_
    dic['Dep'] = token.dep_
    dic['Explanation'] = spacy.explain(token.tag_)
    lis.append(dic)

# %%
data = pd.DataFrame(lis)

# %%
data
# Out:
#            Token    POS  Tags        Dep  \
# 0            The    DET    DT        det
# 1           Zulu  PROPN   NNP   compound
# 2       monarchy   NOUN    NN  nsubjpass
# 3             in    ADP    IN       prep
# 4          South  PROPN   NNP   compound
# ..           ...    ...   ...        ...
# 278  celebration   NOUN    NN       pobj
# 279           of    ADP    IN       prep
# 280          his   PRON  PRP$       poss
# 281   coronation   NOUN    NN       pobj
# 282            .  PUNCT     .      punct
#
#                                    Explanation
# 0                                   determiner
# 1                        noun, proper singular
# 2                       noun, singular or mass
# 3    conjunction, subordinating or preposition
# 4                        noun, proper singular
# ..                                         ...
# 278                     noun, singular or mass
# 279  conjunction, subordinating or preposition
# 280                        pronoun, possessive
# 281                     noun, singular or mass
# 282          punctuation mark, sentence closer
#
# [283 rows x 5 columns]

# %%
l = []
for ent in doc.ents:
    d = {}
    d['entities'] = ent.text
    d['labels'] = ent.label_
    d['Explanation'] = spacy.explain(ent.label_)
    l.append(d)

# %%
entities = pd.DataFrame(l)

# %%
entities
# Out:
#                entities    labels  \
# 0                  Zulu       GPE
# 1          South Africa       GPE
# 2   Goodwill Zwelithini    PERSON
# 3          14 July 1948      DATE
# 4                eighth   ORDINAL
# 5                  Zulu    PERSON
# 6                 eight  CARDINAL
# 7             about 300  CARDINAL
# 8                  Zulu    PERSON
# 9                    US       GPE
# 10          46-year-old      DATE
# 11      Prince Misizulu    PERSON
# 12          65-year-old      DATE
# 13             Thursday      DATE
# 14             29 April      DATE
# 15   the last few years      DATE
# 16             Eswatini       ORG
# 17                  one  CARDINAL
# 18      King Zwelithini    PERSON
# 19                 Zulu    PERSON
# 20             hundreds  CARDINAL
# 21        December 2017      DATE
# 22                 46th   ORDINAL
#
#                                      Explanation
# 0                      Countries, cities, states
# 1                      Countries, cities, states
# 2                    People, including fictional
# 3          Absolute or relative dates or periods
# 4                        "first", "second", etc.
# 5                    People, including fictional
# 6   Numerals that do not fall under another type
# 7   Numerals that do not fall under another type
# 8                    People, including fictional
# 9                      Countries, cities, states
# 10         Absolute or relative dates or periods
# 11                   People, including fictional
# 12         Absolute or relative dates or periods
# 13         Absolute or relative dates or periods
# 14         Absolute or relative dates or periods
# 15         Absolute or relative dates or periods
# 16       Companies, agencies, institutions, etc.
# 17  Numerals that do not fall under another type
# 18                   People, including fictional
# 19                   People, including fictional
# 20  Numerals that do not fall under another type
# 21         Absolute or relative dates or periods
# 22                       "first", "second", etc.

# %%
entities.to_csv('NLPTasks_Assignment', index = False)

# %% [markdown]
# ## Article 2

# %%
url = 'https://www.npr.org/2021/04/28/991683886/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause'
print("Your url is :", url)
page = requests.get(url).text
print(page)
soup = BeautifulSoup(page)
print(soup)
header = soup.find('h1').get_text()
header2 = 'Summary'
date = soup.find('span', attrs = {'class': 'date'}).text
p_tags = soup.findAll('p')
#strip removes space
text = [tags.get_text().strip() for tags in p_tags]
print(text)
#remove everything thats not new line
sentence_list = [ sentence for sentence in text if not '\n' in sentence]
sentence_list = [ sentence for sentence in sentence_list if '.' in sentence]
article = ''.join(sentence_list)
from gensim.summarization import summarize
summary = summarize(article, ratio = 0.15)
doc = docx.Document()
doc.add_heading(header)
doc.add_picture('picture.png')
doc.add_paragraph(date)
doc.add_paragraph(article)
doc.add_heading(header2)
doc.add_paragraph(summary)
doc.save('document.doc')
# Out:
# Your url is : https://www.npr.org/2021/04/28/991683886/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause
# <!doctype html><html class="no-js" lang="en"><head>
#
#
# <!--
#
# nnnnnnnnnnnnnnnnnn ppppppppppppppppppp rrrrrrrrrrrrrrrrrr
# nnnnnnnnnnnnnnnnnn ppppppppppppppppppp rrrrrrrrrrrrrrrrrr
# nnn         nnnnnn ppp          pppppp rrr           rrrr
# nnn   nnnn    nnnn ppp   pppppp   pppp rrr   rrrrrr   rrr
# nnn   nnnnnn   nnn ppp   ppppppp   ppp rrr   rrrrrrrrrrrr
# nnn   nnnnnn   nnn ppp   ppppp    pppp rrr   rrrrrrrrrrrr
# nnn   nnnnnn   nnn ppp           ppppp rrr   rrrrrrrrrrrr
# nnn   nnnnnn   nnn ppp   ppppppppppppp rrr   rrrrrrrrrrrr
# nnnnnnnnnnnnnnnnnn ppp   ppppppppppppp rrrrrrrrrrrrrrrrrr
# nnnnnnnnnnnnnnnnnn ppppppppppppppppppp rrrrrrrrrrrrrrrrrr
#
# We are hiring!
#
# https://n.pr/tech-jobs
#
# -->
#
#
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer', 'GTM-MVD397M');</script>
# <!-- End Google Tag Manager -->
# <script>
#    try {var _sf_startpt=(new Date()).getTime();} catch(e){}
# </script>
# <meta itemscope itemtype="https://schema.org/SpeakableSpecification" itemref="speakable" /><title>'Frightened To Death': Cheerleader Speech Case Gives Supreme Court Pause : NPR</title><meta id="speakable" itemprop="cssSelector" content="[data-is-speakable]" /><meta id="google-site-verification" name="google-site-verification" content="1VqzbDm4ukeFVHOoq5LjIKA2fVKZD-EYv8cXZhKXSfU" /><meta charset="utf-8" /><meta name="robots" content="noarchive,index,follow,max-image-preview:large" /><meta name="Rating" content="General" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" /><meta name="npr-pjax" /><meta name="date" content="2021-04-28" /><link rel="canonical" href="https://www.npr.org/2021/04/28/991683886/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause" /><meta name="description" content="At issue is whether schools may punish students for speech that occurs online and off-campus but may affect school order. The case is the biggest test of student speech rights since 1969." /><link rel="alternate" type="application/rss+xml" title="Law" href="https://feeds.npr.org/1070/rss.xml" /><link rel="alternate" type="application/json" title="Law" href="https://feeds.npr.org/feeds/1070/feed.json" /><link rel="apple-touch-icon" sizes="180x180" href="https://static-assets.npr.org/static/images/favicon/favicon-180x180.png" /><link rel="icon" sizes="96x96" href="https://static-assets.npr.org/static/images/favicon/favicon-96x96.png" /><link rel="icon" sizes="32x32" href="https://static-assets.npr.org/static/images/favicon/favicon-32x32.png" /><link rel="icon" sizes="16x16" href="https://static-assets.npr.org/static/images/favicon/favicon-16x16.png" /><meta property="og:title" content="'Frightened To Death': Cheerleader Speech Case Gives Supreme Court Pause" /><meta property="og:url" content="https://www.npr.org/2021/04/28/991683886/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause" /><meta property="og:type" content="article" /><meta property="og:description" content="At issue is whether schools may punish students for speech that occurs online and off-campus but may affect school order. The case is the biggest test of student speech rights since 1969." /><meta property="og:image" content="https://media.npr.org/assets/img/2021/04/28/ap_21116517664022_wide-9e2bf98e4eb925c100b50b7320d6411a12b9d4b5.jpg?s=1400" /><meta property="og:site_name" content="NPR.org" /><meta property="fb:app_id" content="138837436154588" /><meta property="fb:pages" content="10643211755" /><meta property="article:content_tier" content="free" /><meta property="article:opinion" content="false" /><meta name="twitter:card" content="summary_large_image" /><meta name="twitter:title" content="'Frightened To Death': Cheerleader Speech Case Gives Supreme Court Pause" /><meta name="twitter:site" content="@NPR" /><meta name="twitter:domain" content="npr.org" /><meta name="twitter:image:src" content="https://media.npr.org/assets/img/2021/04/28/ap_21116517664022_wide-9e2bf98e4eb925c100b50b7320d6411a12b9d4b5.jpg?s=1400" /><script id="npr-vars">
#    window.NPR = window.NPR || {};
# NPR.ServerConstants = {"cbHost":"npr.org","webHost":"https:\/\/www.npr.org","legacyWebHost":"https:\/\/legacy.npr.org","stripeServiceHost":"https:\/\/stripe.npr.org","recaptchaV3SiteKey":"6LcdN9IZAAAAAOHT985BJjbzjkBjKSxdxK3GeKSt","placesApiKey":"AIzaSyB_wzlXPVwS4kHRAZsM6scMzUAIsJ6aMZ4","embedHost":"https:\/\/www.npr.org","webHostSecure":"https:\/\/secure.npr.org","identityHost":"https:\/\/identity.api.npr.org","apiHost":"https:\/\/api.npr.org","serverMediaCache":"https:\/\/media.npr.org","googleAnalyticsAccount":"UA-5828686-4","gtmKey":"GTM-MVD397M","nielsenSFCode":"dcr","nielsenAPN":"NPR-dcr","shouldShowHPLocalContent":true,"readingServiceHostname":"https:\/\/reading.api.npr.org","cookieDomain":".npr.org"};
# NPR.serverVars = {"storyId":"991683886","isHiring":true,"facebookAppId":"138837436154588","webpackPublicPath":"https:\/\/bundles.npr.org\/dist\/bundles\/","persistenceVersion":"bef806041a36518bd395564425397040","isBuildOut":true,"topicIds":["P1070","1001","1002"],"primaryTopic":"Law","topics":["Law","News","Home Page Top Stories"],"theme":"1070","programId":"All Things Considered","program":"2","aggIds":["2","1001","1002","1070","191676894","434975886","991524192"],"byline":["Nina Totenberg"],"pubDate":"2021042818","pageTypeId":"1","title":"\u0027Frightened To Death\u0027: Cheerleader Speech Case Gives Supreme Court Pause","publisherOrgId":"1"};
# </script>
# <script type="text/javascript" src="https://static-assets.npr.org/static/javascript/lib/modernizr/modernizr.custom.js">
#    </script>
# <script type="text/javascript" async src="https://js.stripe.com/v3/">
#    </script>
# <script>
#    !function(e){function c(a){if(d[a])return d[a].exports;var f=d[a]={exports:{},id:a,loaded:!1};return e[a].call(f.exports,f,f.exports,c),f.loaded=!0,f.exports}var a=window.webpackJsonp;window.webpackJsonp=function(b,t){for(var n,r,o=0,i=[];o<b.length;o++)r=b[o],f[r]&&i.push.apply(i,f[r]),f[r]=0;for(n in t)if(Object.prototype.hasOwnProperty.call(t,n)){var p=t[n];switch(typeof p){case"object":e[n]=function(c){var a=c.slice(1),d=c[0];return function(c,f,b){e[d].apply(this,[c,f,b].concat(a))}}(p);break;case"function":e[n]=p;break;default:e[n]=e[p]}}for(a&&a(b,t);i.length;)i.shift().call(null,c);if(t[0])return d[0]=0,c(0)};var d={},f={24:0};c.e=function(e,a){if(0===f[e])return a.call(null,c);if(void 0!==f[e])f[e].push(a);else{f[e]=[a];var d=document.getElementsByTagName("head")[0],b=document.createElement("script");b.type="text/javascript",b.charset="utf-8",b.async=!0,b.src=c.p+""+e+"."+{0:"087472ee0f79753ec164",1:"af179743856245cc2fd0",2:"69e9efeb2121d541b8eb",3:"3c8e1847846c5e61332c",4:"771675771c3e238d47e8",5:"f5203d384d7f4567a479",6:"15613287d96e528d47be",7:"7370a68ba2f98ea71f45",8:"33f54085ed8051acbeb9",9:"1887fe85532477b35ade",10:"8e5de15fdd65f07b7062",11:"ee0fbd45dfac122e1f02",12:"06e51755bcda7cffe8ec",13:"55fae8aac3281f833943",14:"6bc597516e3abd1e88d3",15:"32f8131b8cd7739d2c18",16:"1ac69d064e34ff1d69c1",17:"2c9794a1b04070e8374f",18:"599e67633fc453f89902",19:"92521640ae740a46123c",20:"c7ccc5506d2f1f22257c",21:"71e793956c8d08bac166",22:"2bf76857ca1e6cfc6530",23:"7a375d5a6b00560c1a25",25:"34d9f253ee83db56af7c",26:"ffc37b7694d80b02aa97",27:"15c0766ed29481c454bd",28:"5276e27ef656766154c8",29:"7a3dbc86d12b885ec3a3",30:"1f2dd97bdf14ef1a6132",31:"137ede533aa4dcec19b4",32:"65f5a25873a9007e17a7",33:"a5a77612c96c9c29bfdd",34:"112b3e6ded4fff8459c0",35:"9b072e658ccbdbbd2562",36:"99879e1f54ad603d6ea4",37:"76079a3c05dd9318fb21",38:"1fa172a8b115fd2c88df",39:"b9be9c09cf8be2c715ea",40:"0a048843425ad3c5dc2d",41:"a651e1946fd7361ee5c8",42:"80083c86b46bdeb87712",43:"c659e6ad0420692ddce5",44:"5a5946bb03007ce5f1f3",45:"abf9efec0ece10b96fb3",46:"345990d8e86ba2f3fd27",47:"6d2d3b05be73452f327d",48:"a14e7c8d7913e3e8780b",49:"b59d5854b0d4de628c34",50:"10bd3de26a79f6cc2c2d",51:"9399fe07cb4928806874",52:"59d4ae3ed020c022ca00",53:"2e289439a3c3e643e9e1",54:"03f5b6879b355936b538",55:"38ab00f7548d43cd5f13",56:"95cd4e432676a479fe98",57:"3e87dee52c401dcf7ba8",58:"caf1b88a2143d0785d11",59:"777ac613a16bac4ddb68",60:"d0746710081f8635aae7",61:"c32591014286d04d483d",62:"bb112781331100a5c394",63:"1640d255c3630a874c30",64:"e41e4d8371f0454a13b4",65:"a969cd3e272ce937e432",66:"026c52d4d2605845980a",67:"e4658acf1203077549c1",68:"76832128af18eb44ed2f",69:"ab210a2721e55224a401",70:"d0068f26b8215e39d89e",71:"f781f80e28e97fa3dd16",72:"dc6f602b95e12ce993ba",73:"b6f1122a43567fe2380e",74:"b06550c9e6009c140cef",75:"fb2455b2e3aed3afab03",76:"49dae9c25beeec3e8430",77:"94b9eb79b88c4df2572b",78:"e406fdadb369415c1165",79:"68e75bc3decc996da721",80:"0c972b6eb6bd508f22b4",81:"afd349b448617f85ea6c",82:"6ddbf968d2e5ec29a282",83:"dfe117910849e54e8e73",84:"aac42141a2dc9f470788"}[e]+".chunk.js",d.appendChild(b)}},c.m=e,c.c=d,c.p="/dist/bundles/"}(function(e){for(var c in e)if(Object.prototype.hasOwnProperty.call(e,c))switch(typeof e[c]){case"function":break;case"object":e[c]=function(c){var a=c.slice(1),d=e[c[0]];return function(e,c,f){d.apply(this,[e,c,f].concat(a))}}(e[c]);break;default:e[c]=e[e[c]]}return e}([]));
# </script>
# <script type="text/javascript" src="https://bundles.npr.org/dist/bundles/globalNavigationDropdowns-15c0766ed29481c454bd.js">
#    </script>
# <link rel="stylesheet" data-persist="true" media="screen, print" href="https://bundles.npr.org/dist/bundles/persistent-css-abef3c3cafea5565384d.css" /><link rel="stylesheet" data-persist="true" media="screen and (min-width: 768px)" href="https://bundles.npr.org/dist/bundles/persistent_medium-css-abef3c3cafea5565384d.css" /><link rel="stylesheet" data-persist="true" media="screen and (min-width: 1025px)" href="https://bundles.npr.org/dist/bundles/persistent_large-css-abef3c3cafea5565384d.css" /><link rel="preload" data-persist="true" media="screen, print" href="https://bundles.npr.org/dist/bundles/fonts-css-abef3c3cafea5565384d.css" as="style" onload="this.onload=null;this.rel='stylesheet'"  /><link rel="stylesheet" media="screen, print" href="https://bundles.npr.org/dist/bundles/newsStory-css-abef3c3cafea5565384d.css" /><link rel="stylesheet" media="screen" href="https://s.npr.org/include/overridecss/theme1070.css" /><script type="application/ld+json">
#    {"@type":"NewsArticle","publisher":{"@type":"Organization","name":"NPR","logo":{"@type":"ImageObject","url":"https:\/\/media.npr.org\/chrome\/npr-logo.jpg"}},"headline":"'Frightened To Death': Cheerleader Speech Case Gives Supreme Court Pause","mainEntityOfPage":{"@type":"WebPage","@id":"https:\/\/www.npr.org\/2021\/04\/28\/991683886\/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause"},"datePublished":"2021-04-28T18:45:00-04:00","dateModified":"2021-04-28T18:45:00-04:00","author":{"@type":"Person","name":["Nina Totenberg"]},"description":"At issue is whether schools may punish students for speech that occurs online and off-campus but may affect school order. The case is the biggest test of student speech rights since 1969.","image":{"@type":"ImageObject","url":"https:\/\/media.npr.org\/assets\/img\/2021\/04\/28\/ap_21116517664022-25c3c12b4a9f54fd48b355e862aab5a1523adacb.jpg"},"@context":"http:\/\/schema.org"}
# </script>
# <script type="text/javascript">
#    document.domain="www.npr.org";
# </script>
# </head><body id="news" class="news tmplNewsStory  story-layout is-buildout no-transcript has-no-branding id991683886  " data-pjax-modules="util/env images/lazy-load chartbeat comscore metrics nielsen nielsenDCR copyright auto-refresh navigation/global-navigation fitvids googletag dfp globalfooter persistent-audio player/more-options player/audio-module-clickable what-input metrics/doubleclickFloodlight metrics/facebookTracking callout/on-page-callouts global-alerts we-are-hiring ecommerce recommendations/end-of-story-recommendations-callout jw social/share slideshow images/enlargement swfbuilder contentfooter story/sticky-header story/date-tooltip social/sharepop podcast-cards search/faceting-param local/newsletter/callout social/recaptcha">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MVD397M" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="skip-links">
#       <span>Accessibility links</span>   <ul>
#             <li><a href="#mainContent" class="skiplink">Skip to main content</a></li>
#       <li><a href="https://help.npr.org/contact/s/article?name=what-are-the-keyboard-shortcuts-for-using-the-npr-org-audio-player" class="skiplink">Keyboard shortcuts for audio player</a></li>
#    </ul>
# </div>
# <header class="npr-header" id="globalheader" aria-label="NPR header">
# <nav class="navigation">
#     <div class="navigation__top-level-wrap" data-metrics-all data-metrics-category="global navigation">
#         <ul class="navigation__top-level">
#             <li class="navigation__toggle-wrap">
#                 <button id="navigation__toggle--open" class="navigation__toggle navigation__toggle--open" aria-haspopup="true" aria-expanded="false" data-metrics-action="open navigation menu">
#                     Open Navigation Menu
#                 </button>
#             </li>
#
#             <li class="navigation__home">
#                 <a href="/" data-metrics-action="click npr logo">
#                     <img src="https://media.npr.org/chrome_svg/npr-logo.svg" alt="NPR logo"/>
#                 </a>
#             </li>
#
#             <li class="navigation__fifty">
#                 <a href="/series/978593267/50-years-of-npr" data-metrics-action="click npr 50 logo">
#                     <picture class="npr-50-nav-mobile">
#                         <source srcset="https://media.npr.org/assets/npr-50/NPR-50-Mobile.webp?s=200" type="image/webp" />
#                         <source srcset="https://media.npr.org/assets/npr-50/NPR-50-Mobile.png" type="image/png" />
#                         <img src="https://media.npr.org/assets/npr-50/NPR-50-Mobile.png" alt="NPR 50 years logo" />
#                     </picture>
#                     <picture class="npr-50-nav-desktop">
#                         <source srcset="https://media.npr.org/assets/npr-50/NPR-50-Desktop.webp?s=400" type="image/webp" />
#                         <source srcset="https://media.npr.org/assets/npr-50/NPR-50-Desktop.png" type="image/png" />
#                         <img src="https://media.npr.org/assets/npr-50/NPR-50-Desktop.png" alt="NPR 50 years logo" />
#                     </picture>
#                 </a>
#             </li>
#
#             <li id="navigation__station-mount"></li>
#
#             <li id="user-account-dropdown-mount" class="navigation__account"></li>
#
#             <li class="navigation__shop">
#                 <a href="https://shop.npr.org" data-metrics-action="click npr shop">NPR Shop</a>
#             </li>
#
#             <li id="navigation__station-donate-mount"></li>
#         </ul>
#     </div>
#     <section id="main-menu" class="menu menu--main" data-metrics-all data-metrics-category="global navigation">
#         <div class="menu__inner">
#             <header class="menu__header">
#                 <button id="navigation__toggle--close" class="navigation__toggle navigation__toggle--close" aria-haspopup="true" aria-expanded="true" data-metrics-action="close navigation menu">
#                     Close <span>Navigation Menu</span>
#                 </button>
#             </header>
#             <ul class="menu__list">
#                 <li class="menu__item menu__item--home">
#                     <div class="menu__item-inner"><a href="/" data-metrics-action="click npr logo">Home</a></div>
#                 </li>
#                 <li class="menu__item menu__item--news menu__item--has-submenu">
#                     <div class="menu__item-inner">
#                         <a href="/sections/news/" data-metrics-action="click news">News</a>
#                         <button class="menu__toggle-submenu" data-metrics-action="toggle news drawer">Expand/collapse submenu for News</button>
#                     </div>
#
#                     <ul class="submenu submenu--news">
#                         <li class="submenu__item"><a href="/sections/national/" data-metrics-action="click national">National</a></li>
#                         <li class="submenu__item"><a href="/sections/world/" data-metrics-action="click world">World</a></li>
#                         <li class="submenu__item"><a href="/sections/politics/" data-metrics-action="click politics">Politics</a></li>
#                         <li class="submenu__item"><a href="/sections/business/" data-metrics-action="click business">Business</a></li>
#                         <li class="submenu__item"><a href="/sections/health/" data-metrics-action="click health">Health</a></li>
#                         <li class="submenu__item"><a href="/sections/science/" data-metrics-action="click science">Science</a></li>
#                         <li class="submenu__item"><a href="/sections/technology/" data-metrics-action="click technology">Technology</a></li>
#                         <li class="submenu__item"><a href="/sections/codeswitch/" data-metrics-action="click race & culture">Race &amp; Culture</a></li>
#                     </ul>
#                 </li>
#                 <li class="menu__item menu__item--arts-life menu__item--has-submenu">
#                     <div class="menu__item-inner">
#                         <a href="/sections/arts/" data-metrics-action="click arts & life">Arts &amp; Life</a>
#                         <button class="menu__toggle-submenu" data-metrics-action="toggle arts drawer">Expand/collapse submenu for Arts &amp; Life</button>
#                     </div>
#
#                     <ul class="submenu submenu--arts-life">
#                         <li class="submenu__item"><a href="/books/" data-metrics-action="click books">Books</a></li>
#                         <li class="submenu__item"><a href="/sections/movies/" data-metrics-action="click movies">Movies</a></li>
#                         <li class="submenu__item"><a href="/sections/television/" data-metrics-action="click television">Television</a></li>
#                         <li class="submenu__item"><a href="/sections/pop-culture/" data-metrics-action="click pop culture">Pop Culture</a></li>
#                         <li class="submenu__item"><a href="/sections/food/" data-metrics-action="click food">Food</a></li>
#                         <li class="submenu__item"><a href="/sections/art-design/" data-metrics-action="click art & design">Art &amp; Design</a> </li>
#                         <li class="submenu__item"><a href="/sections/performing-arts/" data-metrics-action="click performing arts">Performing Arts</a></li>
#                     </ul>
#                 </li>
#                 <li class="menu__item menu__item--music menu__item--has-submenu">
#                     <div class="menu__item-inner">
#                         <a href="/music/" data-metrics-action="click music">Music</a>
#                         <button class="menu__toggle-submenu" data-metrics-action="toggle music drawer">Expand/collapse submenu for Music</button>
#                     </div>
#
#                     <ul class="submenu submenu--music"><li class="submenu__item">
#     <a href="https://www.npr.org/series/tiny-desk-concerts/" data-metrics-action="click tiny desk">
#         Tiny Desk
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/sections/allsongs/" data-metrics-action="click all songs considered">
#         All Songs Considered
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/sections/music-news/" data-metrics-action="click music news">
#         Music News
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/sections/new-music/" data-metrics-action="click new music">
#         New Music
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/sections/music-features" data-metrics-action="click music features">
#         Music Features
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/series/770565791/npr-music-live-sessions" data-metrics-action="click live sessions">
#         Live Sessions
#     </a>
# </li></ul>
#
#                 </li>
#                 <li class="menu__item menu__item--shows-podcasts menu__item--has-submenu">
#                     <div class="menu__item-inner">
#                         <a href="/programs/" data-metrics-action="click shows & podcasts">Shows &amp; Podcasts</a>
#                         <button class="menu__toggle-submenu" data-metrics-action="toggle programs &amp; podcasts drawer">Expand/collapse submenu for Shows &amp; Podcasts</button>
#                     </div>
#
#                     <div class="submenu submenu--shows-podcasts">
#                         <span class="submenu__category submenu__category--daily">Daily</span>
#                         <ul class="submenu__list submenu__list--daily">
#                             <li class="submenu__item submenu__item--timed submenu__item--weekday hidden">
#                                 <a href="/programs/morning-edition/" data-metrics-action="click morning edition">
#                                     <img src="https://media.npr.org/chrome/programs/logos/morning-edition.jpg" loading="lazy" alt="" />
#                                     Morning Edition
#                                 </a>
#                             </li>
#                             <li class="submenu__item submenu__item--timed submenu__item--saturday hidden" >
#                                 <a href="/programs/weekend-edition-saturday/" data-metrics-action="click weekend edition saturday">
#                                     <img src="https://media.npr.org/assets/img/2019/02/26/we_otherentitiestemplatesat_sq-cbde87a2fa31b01047441e6f34d2769b0287bcd4-s100-c85.png" loading="lazy" alt="" />
#                                     Weekend Edition Saturday
#                                 </a>
#                             </li>
#                             <li class="submenu__item submenu__item--timed submenu__item--sunday hidden">
#                                 <a href="/programs/weekend-edition-sunday/" data-metrics-action="click weekend edition sunday">
#                                     <img src="https://media.npr.org/assets/img/2019/02/26/we_otherentitiestemplatesun_sq-4a03b35e7e5adfa446aec374523a578d54dc9bf5-s100-c85.png" loading="lazy" alt="" />
#                                     Weekend Edition Sunday
#                                 </a>
#                             </li>
#                             <li class="submenu__item">
#                                 <a href="/programs/all-things-considered/" data-metrics-action="click all things considered">
#                                     <img src="https://media.npr.org/chrome/programs/logos/all-things-considered.png" loading="lazy" alt="" />
#                                     All Things Considered
#                                 </a>
#                             </li>
#                             <li class="submenu__item">
#                                 <a href="/programs/fresh-air/" data-metrics-action="click fresh air">
#                                     <img src="https://media.npr.org/chrome/programs/logos/fresh-air.png" loading="lazy" alt="" />
#                                     Fresh Air
#                                 </a>
#                             </li>
#                             <li class="submenu__item">
#                                 <a href="/podcasts/510318/up-first" data-metrics-action="click up first">
#                                     <img src="https://media.npr.org/chrome/programs/logos/up-first.jpg?version=2" loading="lazy" alt="" />
#                                     Up First
#                                 </a>
#                             </li>
#                         </ul>
#                         <span class="submenu__category submenu__category--featured">Featured</span>
#
#                         <ul class="submenu__list submenu__list--featured"><li class="submenu__item">
#     <a href="https://www.npr.org/podcasts/510360/on-our-watch" data-metrics-action="click on our watch">
#         <img src="https://media.npr.org/assets/img/2021/05/12/updatedoowtile_sq-aa83059b11a50ad7f7096afe0ffe3e4de0f6f12a.png?s=100" loading="lazy" alt="" />
#         On Our Watch
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/podcasts/510324/rough-translation" data-metrics-action="click rough translation">
#         <img src="https://media.npr.org/assets/img/2021/05/24/rt_homefront-tile_sq-4d15c8841fa870c2c4114e0705c1a845dcf6a6e4.jpg?s=100" loading="lazy" alt="" />
#         Rough Translation
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/podcasts/510307/invisibilia" data-metrics-action="click invisibilia">
#         <img src="https://media.npr.org/assets/img/2021/04/19/invisibilia-new_sq-62e3ca79b91673b7f161af17db2ee1bd8bc5e2aa.jpeg?s=100" loading="lazy" alt="" />
#         Invisibilia
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/podcasts/510313/how-i-built-this" data-metrics-action="click how i built this with guy raz">
#         <img src="https://media.npr.org/assets/img/2018/08/03/npr_hibt_podcasttile_sq-98320b282169a8cea04a406530e6e7b957665b3f.jpg?s=100" loading="lazy" alt="" />
#         How I Built This with Guy Raz
#     </a>
# </li></ul>
#
#                         <ul class="submenu__list submenu__list--directories">
#                             <li class="submenu__item"><a href="/programs/" data-metrics-action="click all programs">More Shows &amp; Podcasts</a></li>
#                         </ul>
#                     </div>
#                 </li>
#                 <li class="menu__item menu__item--search">
#                     <div class="menu__item-inner">
#                         <a href="/search" id="navigation_dropdown-search" data-metrics-action="click search">Search</a>
#                     </div>
#                 </li>
#                 <li id="user-account-dropdown-mount-two" class="menu__item menu__item--account"></li>
#                 <li class="menu__item menu__item--shop">
#                     <div class="menu__item-inner">
#                         <a href="https://shop.npr.org" data-metrics-action="click npr shop">NPR Shop</a>
#                     </div>
#                 </li>
#             </ul>
#         </div>
#     </section>
#     <section class="menu menu--music" data-metrics-all data-metrics-category="music ecosystem navigation">
#         <div class="menu__list-wrap">
#             <ul class="menu__list menu__list--ecosystem menu__list--music">
#                 <li class="menu__item menu__item--music-home">
#                     <a href="/music/" data-metrics-action="click npr music logo">
#                         <img src="https://media.npr.org/chrome_svg/music-logo-dark.svg" class="music-logo"  alt="NPR Music" />
#                         <img src="https://media.npr.org/chrome_svg/music-logo-light.svg" class="music-logo-alt" alt="NPR Music" />
#                     </a>
#                 </li>
#
#                 <li class="menu__item">
#     <a href="https://www.npr.org/series/tiny-desk-concerts/" data-metrics-action="click tiny desk">
#         Tiny Desk
#     </a>
# </li><li class="menu__item">
#     <a href="https://www.npr.org/sections/allsongs/" data-metrics-action="click all songs considered">
#         All Songs Considered
#     </a>
# </li><li class="menu__item">
#     <a href="https://www.npr.org/sections/music-news/" data-metrics-action="click music news">
#         Music News
#     </a>
# </li><li class="menu__item">
#     <a href="https://www.npr.org/sections/new-music/" data-metrics-action="click new music">
#         New Music
#     </a>
# </li><li class="menu__item">
#     <a href="https://www.npr.org/sections/music-features" data-metrics-action="click music features">
#         Music Features
#     </a>
# </li><li class="menu__item">
#     <a href="https://www.npr.org/series/770565791/npr-music-live-sessions" data-metrics-action="click live sessions">
#         Live Sessions
#     </a>
# </li>
#             </ul>
#         </div>
#     </section>
#     <section class="menu menu--about" data-metrics-all data-metrics-category="about ecosystem navigation">
#         <div class="menu__list-wrap">
#             <ul class="menu__list menu__list--ecosystem menu__list--about">
#                 <li class="menu__item menu__item--about-home"><a href="/about/" data-metrics-action="click about npr">About NPR</a></li>
#                 <li class="menu__item menu__item--about-diversity"><a href="/diversity/" data-metrics-action="click diversity">Diversity</a></li>
#                 <li class="menu__item menu__item--about-organization"><a href="/organization/" data-metrics-action="click organization">Organization</a></li>
#                 <li class="menu__item menu__item--about-support"><a href="/support/" data-metrics-action="click support">Support</a></li>
#                 <li class="menu__item menu__item--about-careers"><a href="/careers/" data-metrics-action="click careers">Careers</a></li>
#                 <li class="menu__item menu__item--about-connect"><a href="/connect/" data-metrics-action="click connect">Connect</a></li>
#                 <li class="menu__item menu__item--about-press"><a href="/press/" data-metrics-action="click press">Press</a></li>
#                 <li class="menu__item menu__item--about-ethics"><a href="/ethics/" data-metrics-action="click ethics">Ethics</a></li>
#             </ul>
#         </div>
#     </section>
# </nav>
# </header><main aria-label="main content"><div class="speakable">
#       <b data-is-speakable>'Frightened To Death': Cheerleader Speech Case Gives Supreme Court Pause</b>   <b data-is-speakable>At issue is whether schools may punish students for speech that occurs online and off-campus but may affect school order. The case is the biggest test of student speech rights since 1969.</b>
# </div>
# <div id="wrapper">
#       <header class="contentheader contentheader--one" data-metrics='{"category":"Law"}' ></header>   <div class="story-sticky-header">
#     <div class="story-sticky-header-inner">
#         <a href="/" class="nprhome nprhome-news"  data-metrics='{&quot;category&quot;:&quot;global navigation&quot;,&quot;action&quot;:&quot;click npr logo&quot;,&quot;label&quot;:&quot;\/&quot;}' >
#             <img src="https://media.npr.org/chrome_svg/npr-logo.svg" alt="NPR logo"/>
#         </a>
#
#         <article id="res991755872" class="bucketwrap resaudio" aria-label="audio-module"><div class="audio-module">
#       <h4 class="audio-module-title">'Frightened To Death': Cheerleader Speech Case Gives Supreme Court Pause</h4>
#    <div class="audio-module-controls-wrap" data-audio='{"uid":"991683886:991755872","available":true,"duration":298,"title":"\u0027Frightened To Death\u0027: Cheerleader Speech Case Gives Supreme Court Pause","audioUrl":"https:\/\/ondemand.npr.org\/anon.npr-mp3\/npr\/atc\/2021\/04\/20210428_atc_snapchat_post_takes_teen_off_cheerleading_squad_and_to_the_supreme_court.mp3?orgId=1&topicId=1070&d=298&p=2&story=991683886&dl=1&siteplayer=true&size=4777318","storyUrl":"https:\/\/www.npr.org\/2021\/04\/28\/991683886\/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause","slug":"Law","program":"All Things Considered","affiliation":"","song":"","artist":"","album":"","track":0,"type":"segment","subtype":"other"}' data-audio-metrics='{"playedFrom":"from sticky header"}'>
#         <div class="audio-module-controls">
#             <a class="audio-module-listen" href="https://ondemand.npr.org/anon.npr-mp3/npr/atc/2021/04/20210428_atc_snapchat_post_takes_teen_off_cheerleading_squad_and_to_the_supreme_court.mp3?orgId=1&amp;topicId=1070&amp;d=298&amp;p=2&amp;story=991683886&amp;dl=1&amp;siteplayer=true&amp;size=4777318&amp;dl=1">
#                 <b class="audio-module-listen-inner">
#                     <b class="audio-module-listen-icon icn-play"></b>
#                     <b class="audio-module-listen-text">
#                         <b class="audio-module-cta">Listen</b>
#                         <b class="audio-module-listen-duration">
#                             <span>&middot; </span>
#                             <span>4:58</span>
#                         </b>
#                     </b>
#                 </b>
#             </a>
#
#                 <time class="audio-module-duration" datetime="P4M,58S">
#                   <span class="audio-module-duration__initial-value">4:58</span>
#                 </time>
#         </div>
#
#
# </div>
#
#
#     <div class="audio-module-tools">
#         <button class="audio-module-tools-toggle"  data-metrics='{&quot;category&quot;:&quot;audio actions&quot;,&quot;action&quot;:&quot;open more options&quot;,&quot;label&quot;:null,&quot;noninteraction&quot;:true}' >
#             <b class="icn-toggle"></b>
#             <b class="label">Toggle more options</b>
#         </button>
#         <ul class="audio-module-more-tools">
#                 <li class="audio-tool audio-tool-download"><a href="https://ondemand.npr.org/anon.npr-mp3/npr/atc/2021/04/20210428_atc_snapchat_post_takes_teen_off_cheerleading_squad_and_to_the_supreme_court.mp3?orgId=1&amp;topicId=1070&amp;d=298&amp;p=2&amp;story=991683886&amp;dl=1&amp;siteplayer=true&amp;size=4777318&amp;dl=1"  data-metrics='{&quot;category&quot;:&quot;audio actions&quot;,&quot;action&quot;:&quot;download audio&quot;,&quot;label&quot;:&quot;991683886&quot;,&quot;noninteraction&quot;:true}'  ><b class="icn-download"></b><b class="audio-tool-label">Download</b></a>
#                 </li>
#
#                 <li class="audio-tool audio-tool-embed" >
#                     <button data-embed-url="https://www.npr.org/player/embed/991683886/991755872"  data-metrics='{&quot;category&quot;:&quot;audio actions&quot;,&quot;action&quot;:&quot;embed audio&quot;,&quot;label&quot;:&quot;991683886&quot;,&quot;noninteraction&quot;:true}' ><b class="button-inner"><b class="icn-embed"></b><b
#                             class="audio-tool-label">Embed</b></b></button>
#
#                     <div class="audio-embed-overlay">
#                         <button class="btn-close"></button>
#                         <label class="embed-label">
#                             <b class="audio-embed-overlay__icon"></b>
#                             <b class="label">Embed</b>
#                             <input class="embed-url embed-url-no-touch" readonly
#                                    value="<iframe src=&quot;https://www.npr.org/player/embed/991683886/991755872&quot; width=&quot;100%&quot; height=&quot;290&quot; frameborder=&quot;0&quot; scrolling=&quot;no&quot; title=&quot;NPR embedded audio player&quot;></iframe>">
#                         </label>
#
#                         <b class="embed-url embed-url-touch">
#                             <code><b class="punctuation">&lt;</b>iframe src="https://www.npr.org/player/embed/991683886/991755872" width="100%" height="290" frameborder="0" scrolling="no" title="NPR embedded audio player"&gt;</code>
#                         </b>
#
#                     </div>
#                 </li>
#
#                 <li class="audio-tool audio-tool-transcript">
#                   <a href="https://www.npr.org/transcripts/991683886"  data-metrics='{&quot;category&quot;:&quot;audio actions&quot;,&quot;action&quot;:&quot;click transcript&quot;,&quot;label&quot;:&quot;991683886&quot;,&quot;noninteraction&quot;:true}' >
#                     <b class="icn-transcript"></b>
#                     <b class="audio-tool-label">Transcript</b>
#                   </a>
#                 </li>
#         </ul>
#     </div>
# </div>
# </article>
#
#         <a href="#" class="title">
#           <b>'Frightened To Death': Cheerleader Speech Case Gives Supreme Court Pause</b>
#           <time datetime="P4M,58S">4:58</time>
#         </a>
#     </div>
# </div>   <section id="main-section"><article class="story"><a id="mainContent"></a><div class="slug-wrap">
#
#     <h3 class="slug">
#         <a href="https://www.npr.org/sections/law/">Law</a>
#     </h3>
# </div>
# <div class="storytitle">
#       <h1>'Frightened To Death': Cheerleader Speech Case Gives Supreme Court Pause</h1>
#    <input type="hidden" id="title991683886" value="'Frightened To Death': Cheerleader Speech Case Gives Supreme Court Pause" />
#    <input type="hidden" id="shortTitle991683886" value="'Frightened To Death': Cheerleader Speech Case Gives Supreme Court Pause" />
#    <input type="hidden" id="modelFullUrl991683886" value="https://www.npr.org/2021/04/28/991683886/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause" />
# </div>
#
# <!-- END CLASS="STORYTITLE" -->
# <div class="story-tools">
#       <div class="share-tools share-tools--primary" aria-label="Share tools">
#             <ul>
#                   <li class="share-tools__service share-tools__service--facebook"><button class="fbStory991683886" data-share-facebook='{"storyId": 991683886 }'  data-metrics='{"action":"Click Facebook","category":"Share Tools","label":"https:\/\/www.npr.org\/2021\/04\/28\/991683886\/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause"}' ><b class="share-tools__service-name">Facebook</b></button></li>
#          <li class="share-tools__service share-tools__service--twitter"><button class="story991683886" data-share-twitter='{"storyId": 991683886 }'  data-metrics='{"action":"Click Twitter","category":"Share Tools","label":"https:\/\/www.npr.org\/2021\/04\/28\/991683886\/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause"}' ><b class="share-tools__service-name">Twitter</b></button></li>
#          <li class="share-tools__service share-tools__service--flipboard"><button class="story991683886" data-share-flipboard='{"storyId": 991683886 }'  data-metrics='{"action":"Click Flipboard","category":"Share Tools","label":"https:\/\/www.npr.org\/2021\/04\/28\/991683886\/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause"}' ><b class="share-tools__service-name">Flipboard</b></button></li>
#          <li class="share-tools__service share-tools__service--email"><button class='share-tools__email-link' data-story-id='991683886'  data-metrics='{"action":"Click Email a Friend","category":"Share Tools","label":"https:\/\/www.npr.org\/2021\/04\/28\/991683886\/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause"}' ><b class="share-tools__service-name">Email</b></button></li>
#       </ul>
#    </div>
#
# <!-- END CLASS="SHARE-TOOLS SHARE-TOOLS--PRIMARY" ARIA-LABEL="SHARE TOOLS" -->
# </div>
#
# <!-- END CLASS="STORY-TOOLS" -->
# <div id="story-meta" class="story-meta has-byline">
#       <div class="story-meta__one">
#             <div class="dateblock">
#     <time datetime="2021-04-28T18:45:00-04:00">
#             <span class="date">April 28, 2021</span><span class="time">6:45 PM ET</span>
#     </time>
# </div>      <div class="program-block">
#                   Heard on          <a href="https://www.npr.org/programs/all-things-considered/2021/04/28/991524192">All Things Considered</a>
#       </div>
#
# <!-- END CLASS="PROGRAM-BLOCK" -->
#    </div>
#
# <!-- END CLASS="STORY-META__ONE" -->
#    <div class="story-meta__two">
#             <div id="storybyline" class="storybyline-wrap linkLocation">
#                   <div class="bucketwrap byline" id="res991683942" previewTitle="bylines">
#                         <div class="byline-container--block">
#                               <div class="byline byline--block byline--has-link" aria-label="Byline">
#     <div class="byline__photo">
#       <a href="https://www.npr.org/people/2101289/nina-totenberg" rel="author"  data-metrics='{"action":"Click Byline","category":"Story Metadata"}' >
#         <picture><source srcset="https://media.npr.org/assets/img/2019/05/28/npr_nina_totenberg_001_sq-cc26f7764ffe0608c663245c7f897e5f2e1eb989-s100-c85.webp" class="img"  type="image/webp" /><source srcset="https://media.npr.org/assets/img/2019/05/28/npr_nina_totenberg_001_sq-cc26f7764ffe0608c663245c7f897e5f2e1eb989-s100-c85.jpg" class="img"  type="image/jpeg" /><img src="https://media.npr.org/assets/img/2019/05/28/npr_nina_totenberg_001_sq-cc26f7764ffe0608c663245c7f897e5f2e1eb989-s100-c85.jpg" class="img"  alt="Nina Totenberg at NPR headquarters in Washington, D.C., May 21, 2019. (photo by Allison Shelley)" /></picture>
#       </a>
#     </div>
#
#   <p class="byline__name byline__name--block">
#     <a href="https://www.npr.org/people/2101289/nina-totenberg" rel="author"  data-metrics='{"action":"Click Byline","category":"Story Metadata"}' >
#       Nina Totenberg
#     </a>
#   </p>
#
#     <a class="byline__social-handle byline__social-handle--1" href="https://www.facebook.com/NinaTotenbergNPR"  data-metrics='{"action":"Click Social Handle","category":"Story Metadata"}' >
#       Facebook
#     </a>
#     <a class="byline__social-handle byline__social-handle--5" href="https://www.twitter.com/NinaTotenberg"  data-metrics='{"action":"Click Social Handle","category":"Story Metadata"}' >
#       Twitter
#     </a>
# </div>
#             </div>
#          </div>
#
# <!-- END CLASS="BUCKETWRAP BYLINE" ID="RES991683942" PREVIEWTITLE="BYLINES" -->
#       </div>
#    </div>
#
# <!-- END CLASS="STORY-META__TWO" -->
# </div>
#
# <!-- END ID="STORY-META" CLASS="STORY-META HAS-BYLINE" -->
# <div id="primaryaudio" class="storylocation linkLocation">
#       <article id="res991755872" class="bucketwrap resaudio primaryaudio" aria-label="audio-module"><div class="audio-module">
#       <h4 class="audio-module-title">'Frightened To Death': Cheerleader Speech Case Gives Supreme Court Pause</h4>
#    <div class="audio-module-controls-wrap" data-audio='{"uid":"991683886:991755872","available":true,"duration":298,"title":"\u0027Frightened To Death\u0027: Cheerleader Speech Case Gives Supreme Court Pause","audioUrl":"https:\/\/ondemand.npr.org\/anon.npr-mp3\/npr\/atc\/2021\/04\/20210428_atc_snapchat_post_takes_teen_off_cheerleading_squad_and_to_the_supreme_court.mp3?orgId=1&topicId=1070&d=298&p=2&story=991683886&dl=1&siteplayer=true&size=4777318","storyUrl":"https:\/\/www.npr.org\/2021\/04\/28\/991683886\/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause","slug":"Law","program":"All Things Considered","affiliation":"","song":"","artist":"","album":"","track":0,"type":"segment","subtype":"other"}' data-audio-metrics='[]'>
#         <div class="audio-module-controls">
#             <a class="audio-module-listen" href="https://ondemand.npr.org/anon.npr-mp3/npr/atc/2021/04/20210428_atc_snapchat_post_takes_teen_off_cheerleading_squad_and_to_the_supreme_court.mp3?orgId=1&amp;topicId=1070&amp;d=298&amp;p=2&amp;story=991683886&amp;dl=1&amp;siteplayer=true&amp;size=4777318&amp;dl=1">
#                 <b class="audio-module-listen-inner">
#                     <b class="audio-module-listen-icon icn-play"></b>
#                     <b class="audio-module-listen-text">
#                         <b class="audio-module-cta">Listen</b>
#                         <b class="audio-module-listen-duration">
#                             <span>&middot; </span>
#                             <span>4:58</span>
#                         </b>
#                     </b>
#                 </b>
#             </a>
#
#                 <time class="audio-module-duration" datetime="P4M,58S">
#                   <span class="audio-module-duration__initial-value">4:58</span>
#                 </time>
#         </div>
#
#
# </div>
#
#
#     <div class="audio-module-tools">
#         <button class="audio-module-tools-toggle"  data-metrics='{&quot;category&quot;:&quot;audio actions&quot;,&quot;action&quot;:&quot;open more options&quot;,&quot;label&quot;:null,&quot;noninteraction&quot;:true}' >
#             <b class="icn-toggle"></b>
#             <b class="label">Toggle more options</b>
#         </button>
#         <ul class="audio-module-more-tools">
#                 <li class="audio-tool audio-tool-download"><a href="https://ondemand.npr.org/anon.npr-mp3/npr/atc/2021/04/20210428_atc_snapchat_post_takes_teen_off_cheerleading_squad_and_to_the_supreme_court.mp3?orgId=1&amp;topicId=1070&amp;d=298&amp;p=2&amp;story=991683886&amp;dl=1&amp;siteplayer=true&amp;size=4777318&amp;dl=1"  data-metrics='{&quot;category&quot;:&quot;audio actions&quot;,&quot;action&quot;:&quot;download audio&quot;,&quot;label&quot;:&quot;991683886&quot;,&quot;noninteraction&quot;:true}'  ><b class="icn-download"></b><b class="audio-tool-label">Download</b></a>
#                 </li>
#
#                 <li class="audio-tool audio-tool-embed" >
#                     <button data-embed-url="https://www.npr.org/player/embed/991683886/991755872"  data-metrics='{&quot;category&quot;:&quot;audio actions&quot;,&quot;action&quot;:&quot;embed audio&quot;,&quot;label&quot;:&quot;991683886&quot;,&quot;noninteraction&quot;:true}' ><b class="button-inner"><b class="icn-embed"></b><b
#                             class="audio-tool-label">Embed</b></b></button>
#
#                     <div class="audio-embed-overlay">
#                         <button class="btn-close"></button>
#                         <label class="embed-label">
#                             <b class="audio-embed-overlay__icon"></b>
#                             <b class="label">Embed</b>
#                             <input class="embed-url embed-url-no-touch" readonly
#                                    value="<iframe src=&quot;https://www.npr.org/player/embed/991683886/991755872&quot; width=&quot;100%&quot; height=&quot;290&quot; frameborder=&quot;0&quot; scrolling=&quot;no&quot; title=&quot;NPR embedded audio player&quot;></iframe>">
#                         </label>
#
#                         <b class="embed-url embed-url-touch">
#                             <code><b class="punctuation">&lt;</b>iframe src="https://www.npr.org/player/embed/991683886/991755872" width="100%" height="290" frameborder="0" scrolling="no" title="NPR embedded audio player"&gt;</code>
#                         </b>
#
#                     </div>
#                 </li>
#
#                 <li class="audio-tool audio-tool-transcript">
#                   <a href="https://www.npr.org/transcripts/991683886"  data-metrics='{&quot;category&quot;:&quot;audio actions&quot;,&quot;action&quot;:&quot;click transcript&quot;,&quot;label&quot;:&quot;991683886&quot;,&quot;noninteraction&quot;:true}' >
#                     <b class="icn-transcript"></b>
#                     <b class="audio-tool-label">Transcript</b>
#                   </a>
#                 </li>
#         </ul>
#     </div>
# </div>
# </article>
# </div>
# <div id="storytext" class="storytext storylocation linkLocation">
#       <div id="res991752434" class="bucketwrap image large">
#             <div
#     class="imagewrap has-source-dimensions"
#     data-crop-type=""
#     style="
#         --source-width: 4987;
#         --source-height: 3740;
#     "
# >
#         <picture>
#             <source srcset="https://media.npr.org/assets/img/2021/04/28/ap_21116517664022-25c3c12b4a9f54fd48b355e862aab5a1523adacb-s1100-c15.webp" data-original="https://media.npr.org/assets/img/2021/04/28/ap_21116517664022-25c3c12b4a9f54fd48b355e862aab5a1523adacb-s1100.webp" class="img lazyOnLoad"  type="image/webp" />
#             <source srcset="https://media.npr.org/assets/img/2021/04/28/ap_21116517664022-25c3c12b4a9f54fd48b355e862aab5a1523adacb-s1100-c15.jpg" data-original="https://media.npr.org/assets/img/2021/04/28/ap_21116517664022-25c3c12b4a9f54fd48b355e862aab5a1523adacb-s1100.jpg" class="img lazyOnLoad"  type="image/jpeg" />
#             <img src="https://media.npr.org/assets/img/2021/04/28/ap_21116517664022-25c3c12b4a9f54fd48b355e862aab5a1523adacb-s1100-c15.jpg" data-original="https://media.npr.org/assets/img/2021/04/28/ap_21116517664022-25c3c12b4a9f54fd48b355e862aab5a1523adacb-s1100.jpg" class="img lazyOnLoad"  alt="" loading="lazy" />
#         </picture>
#         <div class="enlarge-options">
# ...
# </div>
# <div aria-label="Share tools" class="share-tools share-tools--secondary">
# <ul>
# <li class="share-tools__service share-tools__service--facebook"><button class="fbStory991683886" data-metrics='{"action":"Click Facebook","category":"Share Tools","label":"https:\/\/www.npr.org\/2021\/04\/28\/991683886\/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause"}' data-share-facebook='{"storyId": 991683886 }'><b class="share-tools__service-name">Facebook</b></button></li>
# <li class="share-tools__service share-tools__service--twitter"><button class="story991683886" data-metrics='{"action":"Click Twitter","category":"Share Tools","label":"https:\/\/www.npr.org\/2021\/04\/28\/991683886\/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause"}' data-share-twitter='{"storyId": 991683886 }'><b class="share-tools__service-name">Twitter</b></button></li>
# <li class="share-tools__service share-tools__service--flipboard"><button class="story991683886" data-metrics='{"action":"Click Flipboard","category":"Share Tools","label":"https:\/\/www.npr.org\/2021\/04\/28\/991683886\/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause"}' data-share-flipboard='{"storyId": 991683886 }'><b class="share-tools__service-name">Flipboard</b></button></li>
# <li class="share-tools__service share-tools__service--email"><button class="share-tools__email-link" data-metrics='{"action":"Click Email a Friend","category":"Share Tools","label":"https:\/\/www.npr.org\/2021\/04\/28\/991683886\/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause"}' data-story-id="991683886"><b class="share-tools__service-name">Email</b></button></li>
# </ul>
# </div>
# <!-- END CLASS="SHARE-TOOLS SHARE-TOOLS--SECONDARY" ARIA-LABEL="SHARE TOOLS" -->
# <div data-newsletter='{"newsletterId":"news","title":"Daily News","marketingHeader":"Sign Up For The NPR Daily Newsletter","frequency":"each weekday","shortDescription":"Catch up on the latest headlines and unique NPR stories, sent every weekday.","stickyDescription":"Sign up for the NPR Daily newsletter for the latest headlines and unique NPR stories.","contentImage":"https:\/\/media.npr.org\/assets\/img\/2021\/02\/09\/npr-daily.png","staticMarkupDir":"\/buckets\/topics\/header1001.html","brandingDir":"\/branding\/sections\/news\/","brandingLink":"https:\/\/www.npr.org\/sections\/news\/","organizationId":1,"recaptchaSiteKey":"6LfD6CYUAAAAAIBeUekwZ9KCjF4UyLFtu7NWNaEK"}' id="newsletter-acquisition-callout-data">
# </div>
# <!-- END ID="NEWSLETTER-ACQUISITION-CALLOUT-DATA" DATA-NEWSLETTER="{&QUOT;NEWSLETTERID&QUOT;:&QUOT;NEWS&QUOT;,&QUOT;TITLE&QUOT;:&QUOT;DAILY NEWS&QUOT;,&QUOT;MARKETINGHEADER&QUOT;:&QUOT;SIGN UP FOR THE NPR DAILY NEWSLETTER&QUOT;,&QUOT;FREQUENCY&QUOT;:&QUOT;EACH WEEKDAY&QUOT;,&QUOT;SHORTDESCRIPTION&QUOT;:&QUOT;CATCH UP ON THE LATEST HEADLINES AND UNIQUE NPR STORIES, SENT EVERY WEEKDAY.&QUOT;,&QUOT;STICKYDESCRIPTION&QUOT;:&QUOT;SIGN UP FOR THE NPR DAILY NEWSLETTER FOR THE LATEST HEADLINES AND UNIQUE NPR STORIES.&QUOT;,&QUOT;CONTENTIMAGE&QUOT;:&QUOT;HTTPS:\/\/MEDIA.NPR.ORG\/ASSETS\/IMG\/2021\/02\/09\/NPR-DAILY.PNG&QUOT;,&QUOT;STATICMARKUPDIR&QUOT;:&QUOT;\/BUCKETS\/TOPICS\/HEADER1001.HTML&QUOT;,&QUOT;BRANDINGDIR&QUOT;:&QUOT;\/BRANDING\/SECTIONS\/NEWS\/&QUOT;,&QUOT;BRANDINGLINK&QUOT;:&QUOT;HTTPS:\/\/WWW.NPR.ORG\/SECTIONS\/NEWS\/&QUOT;,&QUOT;ORGANIZATIONID&QUOT;:1,&QUOT;RECAPTCHASITEKEY&QUOT;:&QUOT;6LFD6CYUAAAAAIBEUEKWZ9KCJF4UYLFTU7NWNAEK&QUOT;}" -->
# <div id="callout-end-of-story-mount">
# </div>
# <!-- END ID="CALLOUT-END-OF-STORY-MOUNT" -->
# <aside aria-label="recommended stories" class="recommended-stories" id="end-of-story-recommendations-mount"></aside>
# <!-- END ID="END-OF-STORY-RECOMMENDATIONS-MOUNT" CLASS="RECOMMENDED-STORIES" ARIA-LABEL="RECOMMENDED STORIES" -->
# </article><header class="contentheader contentheader--two" data-metrics='{"category":"Law"}'></header><footer aria-label="NPR footer" class="npr-footer" id="npr-footer" role="contentinfo"><div class="npr-footer__content" data-metrics-category="Global Footer" data-metrics-label="Footer">
# <div class="npr-footer__module-group">
# <div class="npr-footer__module">
# <h6 class="npr-footer__header">Read &amp; Listen</h6>
# <ul>
# <li class="npr-footer__item"><a data-metrics-action="Click Homepage" href="/">Home</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click News" href="/sections/news/">News</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Arts &amp; Life" href="/sections/arts/">Arts &amp; Life</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Music" href="/music/">Music</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Podcasts" href="/podcasts/">Podcasts</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Programs" href="/programs/">Programs</a></li>
# </ul>
# </div>
# <div class="npr-footer__module">
# <h6 class="npr-footer__header">Connect</h6>
# <ul>
# <li class="npr-footer__item"><a data-metrics-action="Click Newsletters" href="/newsletters/">Newsletters</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Facebook" href="https://www.facebook.com/NPR/">Facebook</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Twitter" href="https://twitter.com/NPR">Twitter</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Instagram" href="https://www.instagram.com/npr/">Instagram</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Press" href="/press/">Press</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Contact &amp; Help" href="https://help.npr.org/contact/s/">Contact &amp; Help</a></li>
# </ul>
# </div>
# <div class="npr-footer__module">
# <h6 class="npr-footer__header">About NPR</h6>
# <ul>
# <li class="npr-footer__item"><a data-metrics-action="Click Overview" href="/about/">Overview</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Diversity" href="/diversity/">Diversity</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Ethics" href="/ethics/">Ethics</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Finances" href="/about-npr/178660742/public-radio-finances">Finances</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Public Editor" href="/sections/publiceditor/">Public Editor</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Corrections" href="/corrections/">Corrections</a></li>
# </ul>
# </div>
# <div class="npr-footer__module">
# <h6 class="npr-footer__header">Get Involved</h6>
# <ul>
# <li class="npr-footer__item"><a data-metrics-action="Click Support Public Radio" href="/support/">Support Public Radio</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Sponsor NPR" href="/about-npr/186948703/corporate-sponsorship">Sponsor NPR</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click NPR Careers" href="/careers/">NPR Careers</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click NPR Shop" href="https://shop.npr.org/">NPR Shop</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click NPR Events" href="https://www.nprpresents.org">NPR Events</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click NPR Extra" href="/sections/npr-extra/">NPR Extra</a></li>
# </ul>
# </div>
# </div>
# <div class="npr-footer__module npr-footer__module--secondary">
# <ul>
# <li class="npr-footer__item"><a data-metrics-action="Click Terms of Use" href="/about-npr/179876898/terms-of-use">Terms of Use</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Privacy" href="/about-npr/179878450/privacy-policy">Privacy</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Your Privacy Choices" href="/about-npr/179878450/privacy-policy#yourchoices">Your Privacy Choices</a></li>
# <li class="npr-footer__item"><a data-metrics-action="Click Text Only" href="https://text.npr.org/">Text Only</a></li>
# <li class="npr-footer__item"><span class="copy-year"></span></li>
# </ul>
# </div>
# </div></footer><div class="global-stickybar-mount" id="global-stickybar-mount">
# </div>
# </section> <div id="main-sidebar">
# <aside aria-label="advertisement" id="ad-standard-wrap">
# <div class="ad-standard" data-ad-config='{"network":"\/6735\/","site":{"default":"n6735.NPR","mobile":"n6735.NPRMOBILE","sponsor_content":"npr_sponsor_content","default_secondary":"NPRSecondary","mobile_secondary":"NPRMobileSecondary"},"zone":"News_National_Law","targets":{"testserver":"false","isPodcastEpisode":"false","storyId":"991683886","program":"All_Things_Considered","agg":["191676894","434975886"]},"location":"standard","deferred":false,"isBetweenContent":false,"isAggSponsorship":false,"borderClass":""}' id="ad-standard-News_National_Law"></div>
# <p class="left">NPR thanks our sponsors</p><p class="right"><a href="/about-npr/186948703/corporate-sponsorship">Become an NPR sponsor</a></p>
# </aside>
# </div>
# <!-- END ID="MAIN-SIDEBAR" -->
# </div>
# <!-- END ID="WRAPPER" -->
# <section id="global-modal-mount"></section>
# <!-- END ID="GLOBAL-MODAL-MOUNT" -->
# <script type="text/javascript">
#    (function () {
#     var loadPageJs = function () { webpackJsonp([81,24],{0:function(n,t,c){n.exports=c(1769)},1769:function(n,t,c){"use strict";c.p=NPR.serverVars.webpackPublicPath,function(){var n=2,t=function(){--n<1&&function(n){c(102),c(2180),c(729),c(274),c(685),c(1356),c(966),c(750),c(2185),c(749),c(2184),c(2183),c(839),c(2178),c(1510),c(2171),c(260)}(c)}.bind(this);c.e(19,t),c.e(2,t)}.call(this)}}); };
#     if (document.readyState === 'complete') {
#         loadPageJs();
#     } else {
#         window.addEventListener('load', function load() {
#             window.removeEventListener('load', load, false);
#             loadPageJs();
#         });
#     }
# })();
# </script>
# </main><noscript><iframe><img height="1" src="https://www.facebook.com/tr?id=1621557368158968&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></iframe></noscript><script type="text/javascript">
#     var _sf_async_config = _sf_async_config || {};
#     /** CONFIGURATION START **/
#     _sf_async_config.uid = '18888';
#     _sf_async_config.domain = NPR.ServerConstants.cbHost;
#     _sf_async_config.useCanonical = true;
#
#     /** CONFIGURATION END **/
#     (function() {
#         function loadChartbeat() {
#             // Wait until the metric for chartbeat have been setup
#             // in templates/javascript/metrics/chartbeat.js
#             if( !!NPR.ChartbeatLoaded) {
#                 var e = document.createElement('script');
#                 e.setAttribute('language', 'javascript');
#                 e.setAttribute('type', 'text/javascript');
#                 e.setAttribute('src', 'https://static.chartbeat.com/js/chartbeat.js');
#                 document.body.appendChild(e);
#             } else {
#                 setTimeout(loadChartbeat, 1000);
#             }
#         }
#
#         var oldonload = window.onload;
#         window.onload = (typeof window.onload != 'function') ?
#                 loadChartbeat : function() {
#             oldonload();
#             window._sf_endpt = (new Date()).getTime();
#             loadChartbeat();
#         };
#     })();
# </script></body></html><!-- CACHED 1622120558 -->
# ['Nina Totenberg', 'Brandi Levy wears her former cheerleading outfit as she looks at her mobile phone while sitting outside Mahanoy Area High School in Mahanoy City, Pa., on April 4.\n                \n                \n                    \n                    Danna Singer/ACLU/AP\n                    \n                \nhide caption', 'Brandi Levy wears her former cheerleading outfit as she looks at her mobile phone while sitting outside Mahanoy Area High School in Mahanoy City, Pa., on April 4.', 'Facing its biggest student speech case in a half-century, the Supreme Court seemed to be looking for a narrow exit door on Wednesday.', 'At issue was whether schools may punish students for speech that occurs online and off-campus but that may affect school order.', 'The case has been billed as the most important student speech case since 1969. That landmark ruling came at the height of the Vietnam War. Mary Beth Tinker and four other students went to court after they were suspended for wearing black armbands to school to protest the war.', 'By a vote of 7 to 2, the high court ruled at the time for the first time that kids do have First Amendment free speech rights at school, unless school officials reasonably forecast it will cause disruptions.', "Wednesday's case did not involve such serious speech. It was brought by Brandi Levy, a 14-year-old high school cheerleader, who failed to win a promotion from the junior varsity cheer team to the varsity.", '"I was really upset and frustrated at everything," Levy explained in an NPR interview. So, that weekend, she posted a photo of herself and a friend flipping the bird to the camera, with the caption "F*** school F*** softball, F*** cheer, F*** everything."', "Brandi's post hit school like a small-town social media bomb; the school deemed the post disruptive to cheerleader morale and suspended her from the team for the rest of the year. The American Civil Liberties Union took her case to court, claiming that her free speech rights had been violated. And on Wednesday, the Supreme Court faced a question that did not exist in 1969: Can schools punish students for their online but off-campus speech?", 'Justice Stephen Breyer got to the heart of the matter quickly, wondering whether online swearing off-campus should even qualify for school punishment. "If swearing off-campus did [qualify], my goodness, every school in the country would be doing nothing but punishing," he said.', 'Justice Sonia Sotomayor chimed in. "I\'m told by my law clerks that ... among a certain large percentage of the population, how much you curse is a badge of honor," she said. "Kids basically talk to classmates, most of their exchanges have to do with their perceptions of the authoritarian nature of their teachers and others."', 'Justice Brett Kavanaugh, who coaches his daughters\' sports teams, seemed to understand Brandi\'s frustration, acknowledging that even NBA legend Michael Jordan had sore feelings more than 40 years after not making the varsity team in high school. As to this case, said Kavanaugh, "It didn\'t seem like the punishment was tailored to the offense. But how does that fit into the First Amendment Doctrine? Or does it at all?"', 'The argument illustrated just how hard that question is. Siding with the Mahanoy school district in the case, the Justice Department argued that schools could regulate off-campus speech only if it is related to school matters and could cause a "substantial disruption."', '"That means really everything that mentions a school at all is school speech, right?" asked a skeptical Justice Elena Kagan.', 'Deputy Solicitor General Malcolm Stewart tried to offer a nuanced distinction, but Kagan was having none of it. Cutting right to the question of which speech is punishable, she asked, "Can I give you a few hypotheticals, and you just tell me school speech or not school speech?"', '"The student emails his classmates the answer to the geometry homework every day after school?"',  ...

# %%
doc = nlp(summary)

# %% [markdown]
# ### Tokenization

# %%
for token in doc:
    print(token.text, '--->', spacy.explain(token.text))
# Out:
# Brandi ---> None
# Levy ---> None
# wears ---> None
# her ---> None
# former ---> None
# cheerleading ---> None
# outfit ---> None
# as ---> None
# she ---> None
# looks ---> None
# at ---> None
# her ---> None
# mobile ---> None
# phone ---> None
# while ---> None
# sitting ---> None
# outside ---> None
# Mahanoy ---> None
# Area ---> None
# High ---> None
# School ---> None
# in ---> None
# Mahanoy ---> None
# City ---> None
# , ---> punctuation mark, comma
# Pa. ---> None
# , ---> punctuation mark, comma
# on ---> None
# April ---> None
# 4.Facing ---> None
# its ---> None
# biggest ---> None
# student ---> None
# speech ---> None
# case ---> case marking
# in ---> None
# a ---> None
# half ---> None
# - ---> None
# century ---> None
# , ---> punctuation mark, comma
# the ---> None
# Supreme ---> None
# Court ---> None
# seemed ---> None
# to ---> None
# be ---> None
# looking ---> None
# for ---> None
# a ---> None
# narrow ---> None
# exit ---> None
# door ---> None
# on ---> None
# Wednesday ---> None
# . ---> punctuation mark, sentence closer
# At ---> None
# issue ---> None
# was ---> None
# whether ---> None
# schools ---> None
# may ---> None
# punish ---> None
# students ---> None
# for ---> None
# speech ---> None
# that ---> None
# occurs ---> None
# online ---> None
# and ---> None
# off ---> None
# - ---> None
# campus ---> None
# but ---> None
# that ---> None
# may ---> None
# affect ---> None
# school ---> None
# order ---> None
# . ---> punctuation mark, sentence closer
# The ---> None
# case ---> case marking
# has ---> None
# been ---> None
# billed ---> None
# as ---> None
# the ---> None
# most ---> None
# important ---> None
# student ---> None
# speech ---> None
# case ---> case marking
# since ---> None
# 1969 ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# That ---> None
# landmark ---> None
# ruling ---> None
# came ---> None
# at ---> None
# the ---> None
# height ---> None
# of ---> None
# the ---> None
# Vietnam ---> None
# War ---> None
# . ---> punctuation mark, sentence closer
# Mary ---> None
# Beth ---> None
# Tinker ---> None
# and ---> None
# four ---> None
# other ---> None
# students ---> None
# went ---> None
# to ---> None
# court ---> None
# after ---> None
# they ---> None
# were ---> None
# suspended ---> None
# for ---> None
# wearing ---> None
# black ---> None
# armbands ---> None
# to ---> None
# school ---> None
# to ---> None
# protest ---> None
# the ---> None
# war ---> None
# . ---> punctuation mark, sentence closer
# By ---> None
# a ---> None
# vote ---> None
# of ---> None
# 7 ---> None
# to ---> None
# 2 ---> None
# , ---> punctuation mark, comma
# the ---> None
# high ---> None
# court ---> None
# ruled ---> None
# at ---> None
# the ---> None
# time ---> None
# for ---> None
# the ---> None
# first ---> None
# time ---> None
# that ---> None
# kids ---> None
# do ---> None
# have ---> None
# First ---> None
# Amendment ---> None
# free ---> None
# speech ---> None
# rights ---> None
# at ---> None
# school ---> None
# , ---> punctuation mark, comma
# unless ---> None
# school ---> None
# officials ---> None
# reasonably ---> None
# forecast ---> None
# it ---> None
# will ---> None
# cause ---> None
# disruptions ---> None
# . ---> punctuation mark, sentence closer
# Wednesday ---> None
# 's ---> None
# case ---> case marking
# did ---> None
# not ---> None
# involve ---> None
# such ---> None
# serious ---> None
# speech ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# And ---> None
# on ---> None
# Wednesday ---> None
# , ---> punctuation mark, comma
# the ---> None
# Supreme ---> None
# Court ---> None
# faced ---> None
# a ---> None
# question ---> None
# that ---> None
# did ---> None
# not ---> None
# exist ---> None
# in ---> None
# 1969 ---> None
# : ---> punctuation mark, colon or ellipsis
# Can ---> None
# schools ---> None
# punish ---> None
# students ---> None
# for ---> None
# their ---> None
# online ---> None
# but ---> None
# off ---> None
# - ---> None
# campus ---> None
# speech?Justice ---> None
# Stephen ---> None
# Breyer ---> None
# got ---> None
# to ---> None
# the ---> None
# heart ---> None
# of ---> None
# the ---> None
# matter ---> None
# quickly ---> None
# , ---> punctuation mark, comma
# wondering ---> None
# whether ---> None
# online ---> None
# swearing ---> None
# off ---> None
# - ---> None
# campus ---> None
# should ---> None
# even ---> None
# qualify ---> None
# for ---> None
# school ---> None
# punishment ---> None
# . ---> punctuation mark, sentence closer

# %% [markdown]
# ### POS Parsing

# %%
for token in doc:
    print(token.text, '--->', token.pos_, '--->', spacy.explain(token.pos_))
# Out:
# Brandi ---> PROPN ---> proper noun
# Levy ---> PROPN ---> proper noun
# wears ---> VERB ---> verb
# her ---> PRON ---> pronoun
# former ---> ADJ ---> adjective
# cheerleading ---> NOUN ---> noun
# outfit ---> NOUN ---> noun
# as ---> ADP ---> adposition
# she ---> PRON ---> pronoun
# looks ---> VERB ---> verb
# at ---> ADP ---> adposition
# her ---> PRON ---> pronoun
# mobile ---> ADJ ---> adjective
# phone ---> NOUN ---> noun
# while ---> SCONJ ---> subordinating conjunction
# sitting ---> VERB ---> verb
# outside ---> ADP ---> adposition
# Mahanoy ---> PROPN ---> proper noun
# Area ---> PROPN ---> proper noun
# High ---> PROPN ---> proper noun
# School ---> PROPN ---> proper noun
# in ---> ADP ---> adposition
# Mahanoy ---> PROPN ---> proper noun
# City ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# Pa. ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# on ---> ADP ---> adposition
# April ---> PROPN ---> proper noun
# 4.Facing ---> NUM ---> numeral
# its ---> PRON ---> pronoun
# biggest ---> ADJ ---> adjective
# student ---> NOUN ---> noun
# speech ---> NOUN ---> noun
# case ---> NOUN ---> noun
# in ---> ADP ---> adposition
# a ---> DET ---> determiner
# half ---> ADJ ---> adjective
# - ---> PUNCT ---> punctuation
# century ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# the ---> DET ---> determiner
# Supreme ---> PROPN ---> proper noun
# Court ---> PROPN ---> proper noun
# seemed ---> VERB ---> verb
# to ---> PART ---> particle
# be ---> AUX ---> auxiliary
# looking ---> VERB ---> verb
# for ---> ADP ---> adposition
# a ---> DET ---> determiner
# narrow ---> ADJ ---> adjective
# exit ---> NOUN ---> noun
# door ---> NOUN ---> noun
# on ---> ADP ---> adposition
# Wednesday ---> PROPN ---> proper noun
# . ---> PUNCT ---> punctuation
# At ---> ADP ---> adposition
# issue ---> NOUN ---> noun
# was ---> AUX ---> auxiliary
# whether ---> SCONJ ---> subordinating conjunction
# schools ---> NOUN ---> noun
# may ---> AUX ---> auxiliary
# punish ---> VERB ---> verb
# students ---> NOUN ---> noun
# for ---> ADP ---> adposition
# speech ---> NOUN ---> noun
# that ---> DET ---> determiner
# occurs ---> VERB ---> verb
# online ---> ADV ---> adverb
# and ---> CCONJ ---> coordinating conjunction
# off ---> ADP ---> adposition
# - ---> PUNCT ---> punctuation
# campus ---> NOUN ---> noun
# but ---> CCONJ ---> coordinating conjunction
# that ---> DET ---> determiner
# may ---> AUX ---> auxiliary
# affect ---> VERB ---> verb
# school ---> NOUN ---> noun
# order ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# The ---> DET ---> determiner
# case ---> NOUN ---> noun
# has ---> AUX ---> auxiliary
# been ---> AUX ---> auxiliary
# billed ---> VERB ---> verb
# as ---> ADP ---> adposition
# the ---> DET ---> determiner
# most ---> ADV ---> adverb
# important ---> ADJ ---> adjective
# student ---> NOUN ---> noun
# speech ---> NOUN ---> noun
# case ---> NOUN ---> noun
# since ---> SCONJ ---> subordinating conjunction
# 1969 ---> NUM ---> numeral
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# That ---> DET ---> determiner
# landmark ---> NOUN ---> noun
# ruling ---> NOUN ---> noun
# came ---> VERB ---> verb
# at ---> ADP ---> adposition
# the ---> DET ---> determiner
# height ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# Vietnam ---> PROPN ---> proper noun
# War ---> PROPN ---> proper noun
# . ---> PUNCT ---> punctuation
# Mary ---> PROPN ---> proper noun
# Beth ---> PROPN ---> proper noun
# Tinker ---> PROPN ---> proper noun
# and ---> CCONJ ---> coordinating conjunction
# four ---> NUM ---> numeral
# other ---> ADJ ---> adjective
# students ---> NOUN ---> noun
# went ---> VERB ---> verb
# to ---> ADP ---> adposition
# court ---> NOUN ---> noun
# after ---> ADP ---> adposition
# they ---> PRON ---> pronoun
# were ---> AUX ---> auxiliary
# suspended ---> VERB ---> verb
# for ---> ADP ---> adposition
# wearing ---> VERB ---> verb
# black ---> ADJ ---> adjective
# armbands ---> NOUN ---> noun
# to ---> ADP ---> adposition
# school ---> NOUN ---> noun
# to ---> PART ---> particle
# protest ---> VERB ---> verb
# the ---> DET ---> determiner
# war ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# By ---> ADP ---> adposition
# a ---> DET ---> determiner
# vote ---> NOUN ---> noun
# of ---> ADP ---> adposition
# 7 ---> NUM ---> numeral
# to ---> ADP ---> adposition
# 2 ---> NUM ---> numeral
# , ---> PUNCT ---> punctuation
# the ---> DET ---> determiner
# high ---> ADJ ---> adjective
# court ---> NOUN ---> noun
# ruled ---> VERB ---> verb
# at ---> ADP ---> adposition
# the ---> DET ---> determiner
# time ---> NOUN ---> noun
# for ---> ADP ---> adposition
# the ---> DET ---> determiner
# first ---> ADJ ---> adjective
# time ---> NOUN ---> noun
# that ---> DET ---> determiner
# kids ---> NOUN ---> noun
# do ---> AUX ---> auxiliary
# have ---> VERB ---> verb
# First ---> PROPN ---> proper noun
# Amendment ---> PROPN ---> proper noun
# free ---> ADJ ---> adjective
# speech ---> NOUN ---> noun
# rights ---> NOUN ---> noun
# at ---> ADP ---> adposition
# school ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# unless ---> SCONJ ---> subordinating conjunction
# school ---> NOUN ---> noun
# officials ---> NOUN ---> noun
# reasonably ---> ADV ---> adverb
# forecast ---> VERB ---> verb
# it ---> PRON ---> pronoun
# will ---> AUX ---> auxiliary
# cause ---> VERB ---> verb
# disruptions ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# Wednesday ---> PROPN ---> proper noun
# 's ---> PART ---> particle
# case ---> NOUN ---> noun
# did ---> AUX ---> auxiliary
# not ---> PART ---> particle
# involve ---> VERB ---> verb
# such ---> ADJ ---> adjective
# serious ---> ADJ ---> adjective
# speech ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# And ---> CCONJ ---> coordinating conjunction
# on ---> ADP ---> adposition
# Wednesday ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# the ---> DET ---> determiner
# Supreme ---> PROPN ---> proper noun
# Court ---> PROPN ---> proper noun
# faced ---> VERB ---> verb
# a ---> DET ---> determiner
# question ---> NOUN ---> noun
# that ---> DET ---> determiner
# did ---> AUX ---> auxiliary
# not ---> PART ---> particle
# exist ---> VERB ---> verb
# in ---> ADP ---> adposition
# 1969 ---> NUM ---> numeral
# : ---> PUNCT ---> punctuation
# Can ---> AUX ---> auxiliary
# schools ---> NOUN ---> noun
# punish ---> VERB ---> verb
# students ---> NOUN ---> noun
# for ---> ADP ---> adposition
# their ---> PRON ---> pronoun
# online ---> ADJ ---> adjective
# but ---> CCONJ ---> coordinating conjunction
# off ---> ADP ---> adposition
# - ---> PUNCT ---> punctuation
# campus ---> NOUN ---> noun
# speech?Justice ---> NOUN ---> noun
# Stephen ---> PROPN ---> proper noun
# Breyer ---> PROPN ---> proper noun
# got ---> VERB ---> verb
# to ---> ADP ---> adposition
# the ---> DET ---> determiner
# heart ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# matter ---> NOUN ---> noun
# quickly ---> ADV ---> adverb
# , ---> PUNCT ---> punctuation
# wondering ---> VERB ---> verb
# whether ---> SCONJ ---> subordinating conjunction
# online ---> ADV ---> adverb
# swearing ---> VERB ---> verb
# off ---> ADP ---> adposition
# - ---> PUNCT ---> punctuation
# campus ---> NOUN ---> noun
# should ---> AUX ---> auxiliary
# even ---> ADV ---> adverb
# qualify ---> VERB ---> verb
# for ---> ADP ---> adposition
# school ---> NOUN ---> noun
# punishment ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation

# %% [markdown]
# #### Dependency Parsing

# %%
for token in doc:
    print(token.text, '--->', token.dep_, '--->', spacy.explain(token.dep))
# Out:
# Brandi ---> compound ---> None
# Levy ---> nsubj ---> None
# wears ---> ROOT ---> None
# her ---> poss ---> None
# former ---> amod ---> None
# cheerleading ---> compound ---> None
# outfit ---> dobj ---> None
# as ---> mark ---> None
# she ---> nsubj ---> None
# looks ---> advcl ---> None
# at ---> prep ---> None
# her ---> poss ---> None
# mobile ---> amod ---> None
# phone ---> pobj ---> None
# while ---> mark ---> None
# sitting ---> advcl ---> None
# outside ---> prep ---> None
# Mahanoy ---> compound ---> None
# Area ---> compound ---> None
# High ---> compound ---> None
# School ---> pobj ---> None
# in ---> prep ---> None
# Mahanoy ---> compound ---> None
# City ---> pobj ---> None
# , ---> punct ---> None
# Pa. ---> appos ---> None
# , ---> punct ---> None
# on ---> prep ---> None
# April ---> pobj ---> None
# 4.Facing ---> nummod ---> None
# its ---> poss ---> None
# biggest ---> amod ---> None
# student ---> compound ---> None
# speech ---> compound ---> None
# case ---> pobj ---> None
# in ---> prep ---> None
# a ---> det ---> None
# half ---> amod ---> None
# - ---> punct ---> None
# century ---> pobj ---> None
# , ---> punct ---> None
# the ---> det ---> None
# Supreme ---> compound ---> None
# Court ---> nsubj ---> None
# seemed ---> conj ---> None
# to ---> aux ---> None
# be ---> aux ---> None
# looking ---> xcomp ---> None
# for ---> prep ---> None
# a ---> det ---> None
# narrow ---> amod ---> None
# exit ---> compound ---> None
# door ---> pobj ---> None
# on ---> prep ---> None
# Wednesday ---> pobj ---> None
# . ---> punct ---> None
# At ---> prep ---> None
# issue ---> pobj ---> None
# was ---> ROOT ---> None
# whether ---> mark ---> None
# schools ---> nsubj ---> None
# may ---> aux ---> None
# punish ---> ccomp ---> None
# students ---> dobj ---> None
# for ---> prep ---> None
# speech ---> pobj ---> None
# that ---> nsubj ---> None
# occurs ---> relcl ---> None
# online ---> advmod ---> None
# and ---> cc ---> None
# off ---> conj ---> None
# - ---> punct ---> None
# campus ---> npadvmod ---> None
# but ---> cc ---> None
# that ---> nsubj ---> None
# may ---> aux ---> None
# affect ---> conj ---> None
# school ---> compound ---> None
# order ---> dobj ---> None
# . ---> punct ---> None
# The ---> det ---> None
# case ---> nsubjpass ---> None
# has ---> aux ---> None
# been ---> auxpass ---> None
# billed ---> ROOT ---> None
# as ---> prep ---> None
# the ---> det ---> None
# most ---> advmod ---> None
# important ---> amod ---> None
# student ---> compound ---> None
# speech ---> compound ---> None
# case ---> pobj ---> None
# since ---> prep ---> None
# 1969 ---> pobj ---> None
# . ---> punct ---> None
#
#  ---> ROOT ---> None
# That ---> det ---> None
# landmark ---> compound ---> None
# ruling ---> nsubj ---> None
# came ---> ROOT ---> None
# at ---> prep ---> None
# the ---> det ---> None
# height ---> pobj ---> None
# of ---> prep ---> None
# the ---> det ---> None
# Vietnam ---> compound ---> None
# War ---> pobj ---> None
# . ---> punct ---> None
# Mary ---> compound ---> None
# Beth ---> compound ---> None
# Tinker ---> nsubj ---> None
# and ---> cc ---> None
# four ---> nummod ---> None
# other ---> amod ---> None
# students ---> conj ---> None
# went ---> ROOT ---> None
# to ---> prep ---> None
# court ---> pobj ---> None
# after ---> mark ---> None
# they ---> nsubjpass ---> None
# were ---> auxpass ---> None
# suspended ---> advcl ---> None
# for ---> prep ---> None
# wearing ---> pcomp ---> None
# black ---> amod ---> None
# armbands ---> dobj ---> None
# to ---> prep ---> None
# school ---> pobj ---> None
# to ---> aux ---> None
# protest ---> advcl ---> None
# the ---> det ---> None
# war ---> dobj ---> None
# . ---> punct ---> None
# By ---> prep ---> None
# a ---> det ---> None
# vote ---> pobj ---> None
# of ---> prep ---> None
# 7 ---> quantmod ---> None
# to ---> quantmod ---> None
# 2 ---> pobj ---> None
# , ---> punct ---> None
# the ---> det ---> None
# high ---> amod ---> None
# court ---> nsubj ---> None
# ruled ---> ROOT ---> None
# at ---> prep ---> None
# the ---> det ---> None
# time ---> pobj ---> None
# for ---> prep ---> None
# the ---> det ---> None
# first ---> amod ---> None
# time ---> pobj ---> None
# that ---> advmod ---> None
# kids ---> nsubj ---> None
# do ---> aux ---> None
# have ---> relcl ---> None
# First ---> nmod ---> None
# Amendment ---> nmod ---> None
# free ---> amod ---> None
# speech ---> compound ---> None
# rights ---> dobj ---> None
# at ---> prep ---> None
# school ---> pobj ---> None
# , ---> punct ---> None
# unless ---> mark ---> None
# school ---> compound ---> None
# officials ---> nsubj ---> None
# reasonably ---> advmod ---> None
# forecast ---> advcl ---> None
# it ---> nsubj ---> None
# will ---> aux ---> None
# cause ---> ccomp ---> None
# disruptions ---> dobj ---> None
# . ---> punct ---> None
# Wednesday ---> poss ---> None
# 's ---> case ---> None
# case ---> nsubj ---> None
# did ---> aux ---> None
# not ---> neg ---> None
# involve ---> ROOT ---> None
# such ---> amod ---> None
# serious ---> amod ---> None
# speech ---> dobj ---> None
# . ---> punct ---> None
#
#  ---> ROOT ---> None
# And ---> cc ---> None
# on ---> prep ---> None
# Wednesday ---> pobj ---> None
# , ---> punct ---> None
# the ---> det ---> None
# Supreme ---> compound ---> None
# Court ---> nsubj ---> None
# faced ---> ROOT ---> None
# a ---> det ---> None
# question ---> dobj ---> None
# that ---> nsubj ---> None
# did ---> aux ---> None
# not ---> neg ---> None
# exist ---> relcl ---> None
# in ---> prep ---> None
# 1969 ---> pobj ---> None
# : ---> punct ---> None
# Can ---> aux ---> None
# schools ---> nsubj ---> None
# punish ---> ROOT ---> None
# students ---> dobj ---> None
# for ---> prep ---> None
# their ---> poss ---> None
# online ---> amod ---> None
# but ---> cc ---> None
# off ---> conj ---> None
# - ---> punct ---> None
# campus ---> compound ---> None
# speech?Justice ---> pobj ---> None
# Stephen ---> compound ---> None
# Breyer ---> nsubj ---> None
# got ---> advcl ---> None
# to ---> prep ---> None
# the ---> det ---> None
# heart ---> pobj ---> None
# of ---> prep ---> None
# the ---> det ---> None
# matter ---> pobj ---> None
# quickly ---> advmod ---> None
# , ---> punct ---> None
# wondering ---> advcl ---> None
# whether ---> mark ---> None
# online ---> nsubj ---> None
# swearing ---> nsubj ---> None
# off ---> prt ---> None
# - ---> punct ---> None
# campus ---> dobj ---> None
# should ---> aux ---> None
# even ---> advmod ---> None
# qualify ---> ccomp ---> None
# for ---> prep ---> None
# school ---> compound ---> None
# punishment ---> pobj ---> None
# . ---> punct ---> None

# %% [markdown]
# ### Lemmatization

# %%
for token in doc:
    print(token.text, '--->', token.lemma_, '--->', spacy.explain(token.lemma))
# Out:
# Brandi ---> Brandi ---> None
# Levy ---> Levy ---> None
# wears ---> wear ---> None
# her ---> her ---> None
# former ---> former ---> None
# cheerleading ---> cheerleading ---> None
# outfit ---> outfit ---> None
# as ---> as ---> None
# she ---> she ---> None
# looks ---> look ---> None
# at ---> at ---> None
# her ---> her ---> None
# mobile ---> mobile ---> None
# phone ---> phone ---> None
# while ---> while ---> None
# sitting ---> sit ---> None
# outside ---> outside ---> None
# Mahanoy ---> Mahanoy ---> None
# Area ---> Area ---> None
# High ---> High ---> None
# School ---> School ---> None
# in ---> in ---> None
# Mahanoy ---> Mahanoy ---> None
# City ---> City ---> None
# , ---> , ---> None
# Pa. ---> Pa. ---> None
# , ---> , ---> None
# on ---> on ---> None
# April ---> April ---> None
# 4.Facing ---> 4.facing ---> None
# its ---> its ---> None
# biggest ---> big ---> None
# student ---> student ---> None
# speech ---> speech ---> None
# case ---> case ---> None
# in ---> in ---> None
# a ---> a ---> None
# half ---> half ---> None
# - ---> - ---> None
# century ---> century ---> None
# , ---> , ---> None
# the ---> the ---> None
# Supreme ---> Supreme ---> None
# Court ---> Court ---> None
# seemed ---> seem ---> None
# to ---> to ---> None
# be ---> be ---> None
# looking ---> look ---> None
# for ---> for ---> None
# a ---> a ---> None
# narrow ---> narrow ---> None
# exit ---> exit ---> None
# door ---> door ---> None
# on ---> on ---> None
# Wednesday ---> Wednesday ---> None
# . ---> . ---> None
# At ---> at ---> None
# issue ---> issue ---> None
# was ---> be ---> None
# whether ---> whether ---> None
# schools ---> school ---> None
# may ---> may ---> None
# punish ---> punish ---> None
# students ---> student ---> None
# for ---> for ---> None
# speech ---> speech ---> None
# that ---> that ---> None
# occurs ---> occur ---> None
# online ---> online ---> None
# and ---> and ---> None
# off ---> off ---> None
# - ---> - ---> None
# campus ---> campus ---> None
# but ---> but ---> None
# that ---> that ---> None
# may ---> may ---> None
# affect ---> affect ---> None
# school ---> school ---> None
# order ---> order ---> None
# . ---> . ---> None
# The ---> the ---> None
# case ---> case ---> None
# has ---> have ---> None
# been ---> be ---> None
# billed ---> bill ---> None
# as ---> as ---> None
# the ---> the ---> None
# most ---> most ---> None
# important ---> important ---> None
# student ---> student ---> None
# speech ---> speech ---> None
# case ---> case ---> None
# since ---> since ---> None
# 1969 ---> 1969 ---> None
# . ---> . ---> None
#
#  --->
#  ---> None
# That ---> that ---> None
# landmark ---> landmark ---> None
# ruling ---> ruling ---> None
# came ---> come ---> None
# at ---> at ---> None
# the ---> the ---> None
# height ---> height ---> None
# of ---> of ---> None
# the ---> the ---> None
# Vietnam ---> Vietnam ---> None
# War ---> War ---> None
# . ---> . ---> None
# Mary ---> Mary ---> None
# Beth ---> Beth ---> None
# Tinker ---> Tinker ---> None
# and ---> and ---> None
# four ---> four ---> None
# other ---> other ---> None
# students ---> student ---> None
# went ---> go ---> None
# to ---> to ---> None
# court ---> court ---> None
# after ---> after ---> None
# they ---> they ---> None
# were ---> be ---> None
# suspended ---> suspend ---> None
# for ---> for ---> None
# wearing ---> wear ---> None
# black ---> black ---> None
# armbands ---> armband ---> None
# to ---> to ---> None
# school ---> school ---> None
# to ---> to ---> None
# protest ---> protest ---> None
# the ---> the ---> None
# war ---> war ---> None
# . ---> . ---> None
# By ---> by ---> None
# a ---> a ---> None
# vote ---> vote ---> None
# of ---> of ---> None
# 7 ---> 7 ---> None
# to ---> to ---> None
# 2 ---> 2 ---> None
# , ---> , ---> None
# the ---> the ---> None
# high ---> high ---> None
# court ---> court ---> None
# ruled ---> rule ---> None
# at ---> at ---> None
# the ---> the ---> None
# time ---> time ---> None
# for ---> for ---> None
# the ---> the ---> None
# first ---> first ---> None
# time ---> time ---> None
# that ---> that ---> None
# kids ---> kid ---> None
# do ---> do ---> None
# have ---> have ---> None
# First ---> First ---> None
# Amendment ---> Amendment ---> None
# free ---> free ---> None
# speech ---> speech ---> None
# rights ---> right ---> None
# at ---> at ---> None
# school ---> school ---> None
# , ---> , ---> None
# unless ---> unless ---> None
# school ---> school ---> None
# officials ---> official ---> None
# reasonably ---> reasonably ---> None
# forecast ---> forecast ---> None
# it ---> it ---> None
# will ---> will ---> None
# cause ---> cause ---> None
# disruptions ---> disruption ---> None
# . ---> . ---> None
# Wednesday ---> Wednesday ---> None
# 's ---> 's ---> None
# case ---> case ---> None
# did ---> do ---> None
# not ---> not ---> None
# involve ---> involve ---> None
# such ---> such ---> None
# serious ---> serious ---> None
# speech ---> speech ---> None
# . ---> . ---> None
#
#  --->
#  ---> None
# And ---> and ---> None
# on ---> on ---> None
# Wednesday ---> Wednesday ---> None
# , ---> , ---> None
# the ---> the ---> None
# Supreme ---> Supreme ---> None
# Court ---> Court ---> None
# faced ---> face ---> None
# a ---> a ---> None
# question ---> question ---> None
# that ---> that ---> None
# did ---> do ---> None
# not ---> not ---> None
# exist ---> exist ---> None
# in ---> in ---> None
# 1969 ---> 1969 ---> None
# : ---> : ---> None
# Can ---> can ---> None
# schools ---> school ---> None
# punish ---> punish ---> None
# students ---> student ---> None
# for ---> for ---> None
# their ---> their ---> None
# online ---> online ---> None
# but ---> but ---> None
# off ---> off ---> None
# - ---> - ---> None
# campus ---> campus ---> None
# speech?Justice ---> speech?justice ---> None
# Stephen ---> Stephen ---> None
# Breyer ---> Breyer ---> None
# got ---> get ---> None
# to ---> to ---> None
# the ---> the ---> None
# heart ---> heart ---> None
# of ---> of ---> None
# the ---> the ---> None
# matter ---> matter ---> None
# quickly ---> quickly ---> None
# , ---> , ---> None
# wondering ---> wonder ---> None
# whether ---> whether ---> None
# online ---> online ---> None
# swearing ---> swear ---> None
# off ---> off ---> None
# - ---> - ---> None
# campus ---> campus ---> None
# should ---> should ---> None
# even ---> even ---> None
# qualify ---> qualify ---> None
# for ---> for ---> None
# school ---> school ---> None
# punishment ---> punishment ---> None
# . ---> . ---> None

# %% [markdown]
# ### Sentence boundary detection

# %%
list(doc.sents)
# Out:
# [Brandi Levy wears her former cheerleading outfit as she looks at her mobile phone while sitting outside Mahanoy Area High School in Mahanoy City, Pa., on April 4.Facing its biggest student speech case in a half-century, the Supreme Court seemed to be looking for a narrow exit door on Wednesday.,
#  At issue was whether schools may punish students for speech that occurs online and off-campus but that may affect school order.,
#  The case has been billed as the most important student speech case since 1969.,
#  ,
#  That landmark ruling came at the height of the Vietnam War.,
#  Mary Beth Tinker and four other students went to court after they were suspended for wearing black armbands to school to protest the war.,
#  By a vote of 7 to 2, the high court ruled at the time for the first time that kids do have First Amendment free speech rights at school, unless school officials reasonably forecast it will cause disruptions.,
#  Wednesday's case did not involve such serious speech.,
#  ,
#  And on Wednesday, the Supreme Court faced a question that did not exist in 1969:,
#  Can schools punish students for their online but off-campus speech?Justice Stephen Breyer got to the heart of the matter quickly, wondering whether online swearing off-campus should even qualify for school punishment.]

# %%
sentences = list(doc.sents)

# %%
for sentence in sentences:
    print(sentence)
# Out:
# Brandi Levy wears her former cheerleading outfit as she looks at her mobile phone while sitting outside Mahanoy Area High School in Mahanoy City, Pa., on April 4.Facing its biggest student speech case in a half-century, the Supreme Court seemed to be looking for a narrow exit door on Wednesday.
# At issue was whether schools may punish students for speech that occurs online and off-campus but that may affect school order.
# The case has been billed as the most important student speech case since 1969.
#
#
# That landmark ruling came at the height of the Vietnam War.
# Mary Beth Tinker and four other students went to court after they were suspended for wearing black armbands to school to protest the war.
# By a vote of 7 to 2, the high court ruled at the time for the first time that kids do have First Amendment free speech rights at school, unless school officials reasonably forecast it will cause disruptions.
# Wednesday's case did not involve such serious speech.
#
#
# And on Wednesday, the Supreme Court faced a question that did not exist in 1969:
# Can schools punish students for their online but off-campus speech?Justice Stephen Breyer got to the heart of the matter quickly, wondering whether online swearing off-campus should even qualify for school punishment.

# %% [markdown]
# ### Named Entity

# %%
for ent in doc.ents:
    print(ent.text, '---->', ent.label, '---->', spacy.explain(ent.label))
# Out:
# Brandi Levy ----> 380 ----> None
# Mahanoy Area High School ----> 383 ----> None
# Mahanoy City ----> 384 ----> None
# Pa. ----> 384 ----> None
# April 4.Facing ----> 391 ----> None
# a half-century ----> 391 ----> None
# the Supreme Court ----> 383 ----> None
# Wednesday ----> 391 ----> None
# 1969 ----> 391 ----> None
# the Vietnam War ----> 387 ----> None
# Mary Beth Tinker ----> 380 ----> None
# four ----> 397 ----> None
# 7 to 2 ----> 397 ----> None
# first ----> 396 ----> None
# First Amendment ----> 390 ----> None
# Wednesday ----> 391 ----> None
# Wednesday ----> 391 ----> None
# the Supreme Court ----> 383 ----> None
# 1969 ----> 391 ----> None
# Stephen Breyer ----> 380 ----> None

# %% [markdown]
# ### Visualization

# %%
from spacy import displacy

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brandi Levy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  wears her former cheerleading outfit as she looks at her mobile phone while sitting outside
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mahanoy Area High School
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mahanoy City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pa.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 4.Facing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  its biggest student speech case in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a half-century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Supreme Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  seemed to be looking for a narrow exit door on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .At issue was whether schools may punish students for speech that occurs online and off-campus but that may affect school order.The case has been billed as the most important student speech case since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1969
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br>That landmark ruling came at the height of
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Vietnam War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mary Beth Tinker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  other students went to court after they were suspended for wearing black armbands to school to protest the war.By a vote of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7 to 2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , the high court ruled at the time for the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  time that kids do have
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First Amendment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
#  free speech rights at school, unless school officials reasonably forecast it will cause disruptions.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 's case did not involve such serious speech.</br>And on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Supreme Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  faced a question that did not exist in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1969
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# : Can schools punish students for their online but off-campus speech?Justice
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stephen Breyer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  got to the heart of the matter quickly, wondering whether online swearing off-campus should even qualify for school punishment.</div></span>

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="490ad570c9304fd385c1998335c7cceb-0" class="displacy" width="38375" height="1274.5" direction="ltr" style="max-width: none; height: 1274.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Brandi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Levy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">wears</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">former</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">cheerleading</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">outfit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">she</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">looks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">mobile</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">phone</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">while</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">sitting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">outside</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Mahanoy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Area</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">High</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">School</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">Mahanoy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">City,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">Pa.,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">April</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">4.Facing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">biggest</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">student</tspan>
#     <t

# %% [markdown]
# ### Putting it all together

# %%
lis = []

# %%
for token in doc:
    dic = {}
    dic['Token'] = token.text
    dic['POS'] = token.pos_
    dic['Tags'] = token.tag_
    dic['Dep'] = token.dep_
    dic['Explanation'] = spacy.explain(token.tag_)
    lis.append(dic)

# %%
data = pd.DataFrame(lis)

# %%
data
# Out:
#           Token    POS  Tags       Dep  \
# 0        Brandi  PROPN   NNP  compound
# 1          Levy  PROPN   NNP     nsubj
# 2         wears   VERB   VBZ      ROOT
# 3           her   PRON  PRP$      poss
# 4        former    ADJ    JJ      amod
# ..          ...    ...   ...       ...
# 234     qualify   VERB    VB     ccomp
# 235         for    ADP    IN      prep
# 236      school   NOUN    NN  compound
# 237  punishment   NOUN    NN      pobj
# 238           .  PUNCT     .     punct
#
#                                    Explanation
# 0                        noun, proper singular
# 1                        noun, proper singular
# 2            verb, 3rd person singular present
# 3                          pronoun, possessive
# 4                                    adjective
# ..                                         ...
# 234                            verb, base form
# 235  conjunction, subordinating or preposition
# 236                     noun, singular or mass
# 237                     noun, singular or mass
# 238          punctuation mark, sentence closer
#
# [239 rows x 5 columns]

# %%
l = []
for ent in doc.ents:
    d = {}
    d['entities'] = ent.text
    d['labels'] = ent.label_
    d['Explanation'] = spacy.explain(ent.label_)
    l.append(d)

# %%
entities = pd.DataFrame(l)

# %%
entities
# Out:
#                     entities    labels  \
# 0                Brandi Levy    PERSON
# 1   Mahanoy Area High School       ORG
# 2               Mahanoy City       GPE
# 3                        Pa.       GPE
# 4             April 4.Facing      DATE
# 5             a half-century      DATE
# 6          the Supreme Court       ORG
# 7                  Wednesday      DATE
# 8                       1969      DATE
# 9            the Vietnam War     EVENT
# 10          Mary Beth Tinker    PERSON
# 11                      four  CARDINAL
# 12                    7 to 2  CARDINAL
# 13                     first   ORDINAL
# 14           First Amendment       LAW
# 15                 Wednesday      DATE
# 16                 Wednesday      DATE
# 17         the Supreme Court       ORG
# 18                      1969      DATE
# 19            Stephen Breyer    PERSON
#
#                                           Explanation
# 0                         People, including fictional
# 1             Companies, agencies, institutions, etc.
# 2                           Countries, cities, states
# 3                           Countries, cities, states
# 4               Absolute or relative dates or periods
# 5               Absolute or relative dates or periods
# 6             Companies, agencies, institutions, etc.
# 7               Absolute or relative dates or periods
# 8               Absolute or relative dates or periods
# 9   Named hurricanes, battles, wars, sports events...
# 10                        People, including fictional
# 11       Numerals that do not fall under another type
# 12       Numerals that do not fall under another type
# 13                            "first", "second", etc.
# 14                    Named documents made into laws.
# 15              Absolute or relative dates or periods
# 16              Absolute or relative dates or periods
# 17            Companies, agencies, institutions, etc.
# 18              Absolute or relative dates or periods
# 19                        People, including fictional

# %%
entities.to_csv('NLPTasks_Assignment2', index = False)
